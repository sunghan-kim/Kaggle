# %% [markdown]
# # 1. Load Libraries

# %%
from SlackNotifier.notifier import SlackNotifier

api_url = 'https://hooks.slack.com/services/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'
channel = '#ieee-cis-fraud-detection'
sn = SlackNotifier(api_url, channel)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.preprocessing import LabelEncoder

from sklearn.model_selection import train_test_split

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score

import warnings
warnings.filterwarnings('ignore')

import os
print(os.listdir('../../input'))
# Out:
# ['sample_submission.csv', 'test_identity.csv', 'test_transaction.csv', 'train_identity.csv', 'train_transaction.csv']

# %% [markdown]
# # 2. Prepare Data

# %% [markdown]
# ## 2.1 Load Datasets

# %%
df_train_t = pd.read_csv('../../input/train_transaction.csv', index_col='TransactionID')
df_train_i = pd.read_csv('../../input/train_identity.csv', index_col='TransactionID')
df_test_t = pd.read_csv('../../input/test_transaction.csv', index_col='TransactionID')
df_test_i = pd.read_csv('../../input/test_identity.csv', index_col='TransactionID')
sample_submission = pd.read_csv('../../input/sample_submission.csv')

print('train_transaction의 shape : ', df_train_t.shape)
print('train_identity의 shape : ', df_train_i.shape)
print('test_transaction의 shape : ', df_test_t.shape)
print('test_transaction의 shape : ', df_test_i.shape)
# Out:
# train_transaction의 shape :  (590540, 393)
# train_identity의 shape :  (144233, 40)
# test_transaction의 shape :  (506691, 392)
# test_transaction의 shape :  (141907, 40)

# %%
sn.noti('Load Datasets Finished.')

# %% [markdown]
# ## 2.2 Merge Datasets

# %%
df_train = df_train_t.merge(df_train_i, 
                            how='left', 
                            left_index=True, 
                            right_index=True)
df_test = df_test_t.merge(df_test_i, 
                          how='left', 
                          left_index=True, 
                          right_index=True)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 590540 entries, 2987000 to 3577539
# Columns: 433 entries, isFraud to DeviceInfo
# dtypes: float64(399), int64(3), object(31)
# memory usage: 1.9+ GB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 506691 entries, 3663549 to 4170239
# Columns: 432 entries, TransactionDT to DeviceInfo
# dtypes: float64(399), int64(2), object(31)
# memory usage: 1.7+ GB

# %% [markdown]
# ## 2.3 Reduce Memory Usage

# %%
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2    
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)    
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

# %%
df_train = reduce_mem_usage(df_train)
df_test = reduce_mem_usage(df_test)
# Out:
# Mem. usage decreased to 668.22 Mb (66.2% reduction)
# Mem. usage decreased to 583.43 Mb (65.6% reduction)

# %%
sn.noti('Reduce Memory Finished')

# %% [markdown]
# ## 2.4 Divide Features by Categorical and Numerical

# %% [markdown]
# ### 2.4.1 Categorical Features

# %%
# cat_col_t : categorical columns in transaction dataset
cat_col_t = ['ProductCD','addr1','addr2', 'P_emaildomain', 'R_emaildomain', 'TransactionDT']
cat_col_t.extend(['card' + str(x) for x in range(1,7)]) # card1 ~ card6
cat_col_t.extend(['M' + str(x) for x in range(1,10)]) # M1 ~ M9

# cat_col_i : categorical columns in identity dataset
cat_col_i = ['DeviceType', 'DeviceInfo']
cat_col_i.extend(['id_' + str(x) for x in range(12, 39)]) # id_12 ~ id_38

# cat_col : categorical columns in transaction and identity dataset
cat_col = [*cat_col_t, *cat_col_i]

# %% [markdown]
# ### 2.4.2 Numerical Features

# %%
# num_col_t : numerical columns in transaction dataset
num_col_t = [col for col in list(df_train_t.columns) if col not in [*cat_col_t, 'isFraud']]

# num_col_i : numerical columns in identity dataset
num_col_i = [col for col in list(df_train_i.columns) if col not in cat_col_i]

# num_col : numerical columns in transaction and identity dataset
num_col =[*num_col_t, *num_col_i]

# %% [markdown]
# ### 2.4.3 Transaction Dataset

# %%
print("number of transaction dataset's columns : ", df_train_t.shape[1])
print("cat_col_t's length : ", len(cat_col_t))
print("num_col_t's length : ", len(num_col_t))
print("sum of boths : ", len(cat_col_t) + len(num_col_t))
# Out:
# number of transaction dataset's columns :  393
# cat_col_t's length :  21
# num_col_t's length :  371
# sum of boths :  392

# %% [markdown]
# ### 2.4.4 Identity Dataset

# %%
print("number of transaction dataset's columns : ", df_train_i.shape[1])
print("cat_col_i's length : ", len(cat_col_i))
print("num_col_i's length : ", len(num_col_i))
print("sum of boths : ", len(cat_col_i) + len(num_col_i))
# Out:
# number of transaction dataset's columns :  40
# cat_col_i's length :  29
# num_col_i's length :  11
# sum of boths :  40

# %%
sn.noti('Prepare Data Finished!')

# %% [markdown]
# # 3. Summary of Features

# %% [markdown]
# ## 3.1 Summary of Categorical Features

# %%
def make_cat_summary(df, features) :

    summary = df[features].dtypes.reset_index()
    summary.rename(columns={'index': 'Name', 0: 'Dtype'}, inplace=True)
    summary['DataSets'] = ['transaction' if col in cat_col_t else 'identity' for col in features]
    summary['NullCnt'] = [df[col].isnull().sum() for col in features]
    summary['NullRt'] = [np.round((df[col].isnull().sum())/df.shape[0], 2) for col in features]
    summary['UniqueCnt'] = [df[col].nunique() for col in features]
    Values = []
    for col in features :
        if df[col].nunique() <= 5 :
            val = list(df[col].value_counts().reset_index()['index'])
            val.sort()
            Values.append(', '.join(str(v) for v in val))
        else :
            Values.append('-')    
    summary['Values'] = Values
    summary['MinValue'] = [df.loc[df[col].notnull(), col].min() for col in features]
    summary['MaxValue'] = [df.loc[df[col].notnull(), col].max() for col in features]
    
    return summary

# %%
cat_summary = make_cat_summary(df_train, cat_col)
cat_summary.head()
# Out:
#             Name    Dtype     DataSets  NullCnt  NullRt  UniqueCnt  \
# 0      ProductCD   object  transaction        0    0.00          5
# 1          addr1  float16  transaction    65706    0.11        332
# 2          addr2  float16  transaction    65706    0.11         74
# 3  P_emaildomain   object  transaction    94456    0.16         59
# 4  R_emaildomain   object  transaction   453249    0.77         60
#
#           Values MinValue   MaxValue
# 0  C, H, R, S, W        C          W
# 1              -      100        540
# 2              -       10        102
# 3              -  aim.com  ymail.com
# 4              -  aim.com  ymail.com

# %% [markdown]
# ## 3.2 Summary of Numerical Features

# %%
def make_num_summary(df, features) :
    
    summary = df[features].dtypes.reset_index()
    summary.rename(columns={'index': 'Name', 0: 'Dtype'}, inplace=True)
    summary['DataSets'] = ['transaction' if col in num_col_t else 'identity' for col in features]
    summary['NullCnt'] = [df[col].isnull().sum() for col in features]
    summary['NullRt'] = [np.round((df[col].isnull().sum())/df.shape[0], 2) for col in features]
    summary['MinValue'] = [df.loc[df[col].notnull(), col].min() for col in features]
    summary['Q25'] = [df[col].quantile([0.25]).values[0] for col in features]
    summary['Q50'] = [df[col].quantile([0.50]).values[0] for col in features]
    summary['Q75'] = [df[col].quantile([0.75]).values[0] for col in features]
    summary['MaxValue'] = [df.loc[df[col].notnull(), col].max() for col in features]
    summary['Mean'] = [df.loc[df[col].notnull(), col].mean() for col in features]
    summary['Std'] = [df.loc[df[col].notnull(), col].std() for col in features]

    return summary

# %%
num_summary = make_num_summary(df_train, num_col)
num_summary.head()
# Out:
#              Name    Dtype     DataSets  NullCnt  NullRt  MinValue      Q25  \
# 0  TransactionAmt  float16  transaction        0    0.00  0.250977  43.3125
# 1           dist1  float16  transaction   352271    0.60  0.000000   3.0000
# 2           dist2  float16  transaction   552913    0.94  0.000000   7.0000
# 3              C1  float16  transaction        0    0.00  0.000000   1.0000
# 4              C2  float16  transaction        0    0.00  0.000000   1.0000
#
#      Q50    Q75  MaxValue  Mean  Std
# 0  68.75  125.0   31936.0   NaN  NaN
# 1   8.00   24.0   10288.0   NaN  NaN
# 2  37.00  206.0   11624.0   inf  inf
# 3   1.00    3.0    4684.0   NaN  NaN
# 4   1.00    3.0    5692.0   NaN  NaN

# %%
sn.noti('Summary Finished')

# %% [markdown]
# # 4. Feature Engineering

# %% [markdown]
# ## 4.1 Define Functions

# %%
def value_acc_freq(df, col) :
        
    df_vc = df[col].value_counts().reset_index()
    df_vc.rename(columns={'index': 'value', col: 'cnt'}, inplace=True)
    df_vc['accCntRt'] = df_vc['cnt'].cumsum() / len(df[df[col].notnull()])
    
    return df_vc

# %%
def replace_to_others(df, col, rate=None, cnt=None) :
    
    df_vc = df[col].value_counts().reset_index()
    df_vc.rename(columns={'index': 'value', col: 'cnt'}, inplace=True)
    df_vc['accCntRt'] = df_vc['cnt'].cumsum() / len(df[df[col].notnull()])
    target_list = []
    
    if rate != None :
        target_list = list(df_vc[df_vc['accCntRt'] >= float(rate)]['value'])
    if cnt != None :
        target_list = list(df_vc[df_vc['cnt'] < int(10)]['value'])
        
    dataType = str(df_vc['value'].values.dtype)
    replace_value = 'OTHERS'
    if dataType.find('int') == 0 :
        replace_value = int(99999)
    elif dataType.find('float') == 0 :
        replace_value = float(99999)
    
    df.loc[df[col].isin(target_list), col] = replace_value

# %% [markdown]
# ## 4.2 Feature Engineering for Categorical Features

# %%
def cat_feature_engineering(df) :
    # addr1
    replace_to_others(df, 'addr1', rate=0.95)

    # addr2
    replace_to_others(df, 'addr2', cnt=10)

    # P_emaildomain
    df.loc[df['P_emaildomain'].str.contains('gmail', na=False), 'P_emaildomain'] = 'GMAIL'
    df.loc[df['P_emaildomain'].str.contains('yahoo', na=False), 'P_emaildomain'] = 'YAHOO'
    df.loc[df['P_emaildomain'].str.contains('hotmail', na=False), 'P_emaildomain'] = 'HOTMAIL'
    df.loc[df['P_emaildomain'].str.contains('live', na=False), 'P_emaildomain'] = 'LIVE'
    df.loc[df['P_emaildomain'].str.contains('netzero', na=False), 'P_emaildomain'] = 'NETZERO'
    df.loc[df['P_emaildomain'].str.contains('outlook', na=False), 'P_emaildomain'] = 'OUTLOOK'
    replace_to_others(df, 'P_emaildomain', cnt=250)

    # R_emaildomain
    df.loc[df['R_emaildomain'].str.contains('gmail', na=False), 'R_emaildomain'] = 'GMAIL'
    df.loc[df['R_emaildomain'].str.contains('yahoo', na=False), 'R_emaildomain'] = 'YAHOO'
    df.loc[df['R_emaildomain'].str.contains('hotmail', na=False), 'R_emaildomain'] = 'HOTMAIL'
    df.loc[df['R_emaildomain'].str.contains('live', na=False), 'R_emaildomain'] = 'LIVE'
    df.loc[df['R_emaildomain'].str.contains('netzero', na=False), 'R_emaildomain'] = 'NETZERO'
    df.loc[df['R_emaildomain'].str.contains('outlook', na=False), 'R_emaildomain'] = 'OUTLOOK'
    replace_to_others(df, 'R_emaildomain', cnt=80)

    # TransactionDT
    # Reference : https://www.kaggle.com/shkim4738/extensive-eda-and-modeling-xgb-hyperopt
    import datetime

    START_DATE = '2017-12-01'
    startdate = datetime.datetime.strptime(START_DATE, '%Y-%m-%d')
    df['Date'] = df['TransactionDT'].apply(lambda x : (startdate + datetime.timedelta(seconds=x)))

    df['Weekdays'] = df['Date'].dt.dayofweek
    df['Hours'] = df['Date'].dt.hour
    df['Days'] = df['Date'].dt.day

    df.drop(['Date'], axis=1, inplace=True)

    # DeviceInfo
    df.loc[df['DeviceInfo'].str.contains('SAMSUNG', na=False), 'DeviceInfo'] = 'SAMSUNG'
    df.loc[df['DeviceInfo'].str.contains('SM', na=False), 'DeviceInfo'] = 'SM'
    df.loc[df['DeviceInfo'].str.contains('rv', na=False), 'DeviceInfo'] = 'RV'
    df.loc[df['DeviceInfo'].str.contains('Moto', na=False), 'DeviceInfo'] = 'MOTO'
    df.loc[df['DeviceInfo'].str.contains('HUAWEI', na=False), 'DeviceInfo'] = 'HUAWEI'
    df.loc[df['DeviceInfo'].str.contains('Huawei', na=False), 'DeviceInfo'] = 'HUAWEI'
    df.loc[df['DeviceInfo'].str.contains('LG-', na=False), 'DeviceInfo'] = 'LG'
    df.loc[df['DeviceInfo'].str.contains('Android', na=False), 'DeviceInfo'] = 'ANDROID'
    df.loc[df['DeviceInfo'].str.contains('Linux', na=False), 'DeviceInfo'] = 'LINUX'
    df.loc[df['DeviceInfo'].str.contains('HTC', na=False), 'DeviceInfo'] = 'HTC'
    df.loc[df['DeviceInfo'].str.contains('Hisense', na=False), 'DeviceInfo'] = 'HISENSE'
    df.loc[df['DeviceInfo'].str.contains('Blade', na=False), 'DeviceInfo'] = 'BLADE'
    df.loc[df['DeviceInfo'].str.contains('BLADE', na=False), 'DeviceInfo'] = 'BLADE'
    df.loc[df['DeviceInfo'].str.contains('ASUS', na=False), 'DeviceInfo'] = 'ASUS'
    df.loc[df['DeviceInfo'].str.contains('Redmi', na=False), 'DeviceInfo'] = 'REDMI'
    df.loc[df['DeviceInfo'].str.contains('iOS', na=False), 'DeviceInfo'] = 'iOS'
    df.loc[df['DeviceInfo'].str.contains('MacOS', na=False), 'DeviceInfo'] = 'MacOS'
    device = ['SAMSUNG','SM','RV','MOTO','HUAWEI','LG','ANDROID','LINUX','HTC','HISENSE','BLADE','ASUS','REDMI',
              'Windows','iOS', 'MacOS', 'Trident/7.0']
    df.loc[(~df['DeviceInfo'].isin(device)) & (df['DeviceInfo'].notnull()), 'DeviceInfo'] = 'OTHERS'

    # id_30
    df.loc[df['id_30'].str.contains('Windows', na=False), 'id_30'] = 'WINDOWS'
    df.loc[df['id_30'].str.contains('iOS', na=False), 'id_30'] = 'iOS'
    df.loc[df['id_30'].str.contains('Mac OS X', na=False), 'id_30'] = 'MacOS'
    df.loc[df['id_30'].str.contains('Android', na=False), 'id_30'] = 'ANDROID'

    # id_31
    df.loc[df['id_31'].str.contains('chrome', na=False), 'id_31'] = 'CHROME'
    df.loc[df['id_31'].str.contains('firefox', na=False), 'id_31'] = 'FIREFOX'
    df.loc[df['id_31'].str.contains('edge', na=False), 'id_31'] = 'EDGE'
    df.loc[df['id_31'].str.contains('ie ', na=False), 'id_31'] = 'IE'
    df.loc[df['id_31'].str.contains('safari', na=False), 'id_31'] = 'SAFARI'
    df.loc[df['id_31'].str.contains('opera', na=False), 'id_31'] = 'OPERA'
    df.loc[df['id_31'].str.contains('samsung', na=False), 'id_31'] = 'SAMSUNG'
    df.loc[df['id_31'].str.contains('Samsung', na=False), 'id_31'] = 'SAMSUNG'
    df.loc[df['id_31'].str.contains('android', na=False), 'id_31'] = 'ANDROID'
    df.loc[df['id_31'].str.contains('Android', na=False), 'id_31'] = 'ANDROID'
    device2 = ['CHROME','FIREFOX','EDGE','IE','SAFARI','OPERA','SAMSUNG','ANDROID']
    df.loc[(~df['id_31'].isin(device2)) & (df['id_31'].notnull()), 'id_31'] = 'OTHERS'

    # id_33
    replace_to_others(df, 'id_33', cnt=10)

# %%
cat_feature_engineering(df_train)
cat_feature_engineering(df_test)

# %%
cat_col_t.extend(['Weekdays','Hours','Days'])
cat_col = [*cat_col_t, *cat_col_i]

# %% [markdown]
# ## 4.3 Feature Engineering for Numerical Features

# %% [markdown]
# 생략

# %% [markdown]
# ## 4.4 Missinig Values

# %%
cat_col_null_over90 = list(cat_summary.loc[cat_summary['NullRt'] >= float(0.9), 'Name'].values)
num_col_null_over90 = list(num_summary.loc[num_summary['NullRt'] >= float(0.9), 'Name'].values)
col_null_over90 = [*cat_col_null_over90, *num_col_null_over90]

# %%
df_train = df_train.drop(col_null_over90, axis=1)
df_test = df_test.drop(col_null_over90, axis=1)

# %%
cat_col = [col for col in cat_col if col not in cat_col_null_over90]
num_col = [col for col in num_col if col not in num_col_null_over90]

# %% [markdown]
# ## 4.5 Encoding

# %%
for col in cat_col :
    if col in df_train.columns :
        le = LabelEncoder()
        le.fit(list(df_train[col].astype(str).values)
               + list(df_test[col].astype(str).values))
        df_train[col] = le.transform(list(df_train[col].astype(str).values))
        df_test[col] = le.transform(list(df_test[col].astype(str).values))

# %%
sn.noti('Feature Engineering Finished!')

# %% [markdown]
# # 5. Modeling

# %% [markdown]
# ## 5.1 Set X, y

# %%
y_train = df_train['isFraud']
X_train = df_train.drop('isFraud', axis=1)
X_test = df_test

# %% [markdown]
# ## 5.2 Make Validation set

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.2, random_state=0)

# %%
train_cnt = y_train.count()
valid_cnt = y_valid.count()
print('학습 세트 shape : {0}, 검증 세트 shape : {1}'.format(X_train.shape, X_valid.shape))

print('학습 세트 레이블 값 분포 비율')
print(y_train.value_counts()/train_cnt)
print('\n검증 세트 레이블 값 분포 비율')
print(y_valid.value_counts()/valid_cnt)
# Out:
# 학습 세트 shape : (472432, 422), 검증 세트 shape : (118108, 422)
# 학습 세트 레이블 값 분포 비율
# 0    0.964839
# 1    0.035161
# Name: isFraud, dtype: float64
#
# 검증 세트 레이블 값 분포 비율
# 0    0.965692
# 1    0.034308
# Name: isFraud, dtype: float64

# %% [markdown]
# ## 5.3 모델 학습

# %%
# %%time
from lightgbm import LGBMClassifier

lgbm_clf = LGBMClassifier(n_estimators=500, random_state=0)

evals = [(X_valid, y_valid)]
lgbm_clf.fit(X_train, y_train,
             early_stopping_rounds=100,
             eval_metric='auc',
             eval_set=evals,
             verbose=True)

lgbm_auc_score = roc_auc_score(y_valid, lgbm_clf.predict_proba(X_valid)[:,1], average='macro')
print('ROC AUC : {0:.4f}'.format(lgbm_auc_score))
sn.noti('LightGBM ROC AUC Score : {0:.4f}'.format(lgbm_auc_score))
# Out:
# [1]	valid_0's binary_logloss: 0.126366	valid_0's auc: 0.804378
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's binary_logloss: 0.120267	valid_0's auc: 0.849366
# [3]	valid_0's binary_logloss: 0.116304	valid_0's auc: 0.856252
# [4]	valid_0's binary_logloss: 0.113008	valid_0's auc: 0.859701
# [5]	valid_0's binary_logloss: 0.110035	valid_0's auc: 0.865047
# [6]	valid_0's binary_logloss: 0.107565	valid_0's auc: 0.869407
# [7]	valid_0's binary_logloss: 0.105597	valid_0's auc: 0.871918
# [8]	valid_0's binary_logloss: 0.103855	valid_0's auc: 0.873486
# [9]	valid_0's binary_logloss: 0.10242	valid_0's auc: 0.874717
# [10]	valid_0's binary_logloss: 0.100876	valid_0's auc: 0.876362
# [11]	valid_0's binary_logloss: 0.0996368	valid_0's auc: 0.877128
# [12]	valid_0's binary_logloss: 0.0984714	valid_0's auc: 0.879384
# [13]	valid_0's binary_logloss: 0.0974617	valid_0's auc: 0.879942
# [14]	valid_0's binary_logloss: 0.0964328	valid_0's auc: 0.882679
# [15]	valid_0's binary_logloss: 0.0955687	valid_0's auc: 0.883459
# [16]	valid_0's binary_logloss: 0.0947282	valid_0's auc: 0.884668
# [17]	valid_0's binary_logloss: 0.093973	valid_0's auc: 0.88642
# [18]	valid_0's binary_logloss: 0.0933358	valid_0's auc: 0.88792
# [19]	valid_0's binary_logloss: 0.0927443	valid_0's auc: 0.888929
# [20]	valid_0's binary_logloss: 0.0921279	valid_0's auc: 0.889819
# [21]	valid_0's binary_logloss: 0.0915882	valid_0's auc: 0.891006
# [22]	valid_0's binary_logloss: 0.0909653	valid_0's auc: 0.892223
# [23]	valid_0's binary_logloss: 0.0903833	valid_0's auc: 0.89374
# [24]	valid_0's binary_logloss: 0.0898678	valid_0's auc: 0.894726
# [25]	valid_0's binary_logloss: 0.0893989	valid_0's auc: 0.895656
# [26]	valid_0's binary_logloss: 0.0887853	valid_0's auc: 0.897304
# [27]	valid_0's binary_logloss: 0.0884055	valid_0's auc: 0.897774
# [28]	valid_0's binary_logloss: 0.0881437	valid_0's auc: 0.897999
# [29]	valid_0's binary_logloss: 0.0877742	valid_0's auc: 0.898858
# [30]	valid_0's binary_logloss: 0.0873815	valid_0's auc: 0.899774
# [31]	valid_0's binary_logloss: 0.0870655	valid_0's auc: 0.900398
# [32]	valid_0's binary_logloss: 0.0867366	valid_0's auc: 0.900985
# [33]	valid_0's binary_logloss: 0.0864539	valid_0's auc: 0.901333
# [34]	valid_0's binary_logloss: 0.0861498	valid_0's auc: 0.902086
# [35]	valid_0's binary_logloss: 0.085824	valid_0's auc: 0.902941
# [36]	valid_0's binary_logloss: 0.0855086	valid_0's auc: 0.903701
# [37]	valid_0's binary_logloss: 0.0851035	valid_0's auc: 0.904847
# [38]	valid_0's binary_logloss: 0.084835	valid_0's auc: 0.905306
# [39]	valid_0's binary_logloss: 0.0845816	valid_0's auc: 0.905903
# [40]	valid_0's binary_logloss: 0.0841179	valid_0's auc: 0.906899
# [41]	valid_0's binary_logloss: 0.0837625	valid_0's auc: 0.908293
# [42]	valid_0's binary_logloss: 0.0834734	valid_0's auc: 0.908916
# [43]	valid_0's binary_logloss: 0.0831291	valid_0's auc: 0.909704
# [44]	valid_0's binary_logloss: 0.0828482	valid_0's auc: 0.910038
# [45]	valid_0's binary_logloss: 0.0826651	valid_0's auc: 0.9103
# [46]	valid_0's binary_logloss: 0.0823922	valid_0's auc: 0.910645
# [47]	valid_0's binary_logloss: 0.0821819	valid_0's auc: 0.911008
# [48]	valid_0's binary_logloss: 0.0819332	valid_0's auc: 0.911606
# [49]	valid_0's binary_logloss: 0.0816772	valid_0's auc: 0.912027
# [50]	valid_0's binary_logloss: 0.0815234	valid_0's auc: 0.912834
# [51]	valid_0's binary_logloss: 0.0813065	valid_0's auc: 0.913274
# [52]	valid_0's binary_logloss: 0.0809184	valid_0's auc: 0.914653
# [53]	valid_0's binary_logloss: 0.0807179	valid_0's auc: 0.915157
# [54]	valid_0's binary_logloss: 0.0805272	valid_0's auc: 0.915563
# [55]	valid_0's binary_logloss: 0.0802905	valid_0's auc: 0.915806
# [56]	valid_0's binary_logloss: 0.080145	valid_0's auc: 0.916137
# [57]	valid_0's binary_logloss: 0.0799259	valid_0's auc: 0.916737
# [58]	valid_0's binary_logloss: 0.0797507	valid_0's auc: 0.9171
# [59]	valid_0's binary_logloss: 0.0795543	valid_0's auc: 0.917624
# [60]	valid_0's binary_logloss: 0.0793592	valid_0's auc: 0.917913
# [61]	valid_0's binary_logloss: 0.0791021	valid_0's auc: 0.918489
# [62]	valid_0's binary_logloss: 0.0789608	valid_0's auc: 0.918756
# [63]	valid_0's binary_logloss: 0.0787996	valid_0's auc: 0.919002
# [64]	valid_0's binary_logloss: 0.0786578	valid_0's auc: 0.919233
# [65]	valid_0's binary_logloss: 0.0784888	valid_0's auc: 0.919458
# [66]	valid_0's binary_logloss: 0.078357	valid_0's auc: 0.919612
# [67]	valid_0's binary_logloss: 0.0782247	valid_0's auc: 0.91984
# [68]	valid_0's binary_logloss: 0.0780794	valid_0's auc: 0.920047
# [69]	valid_0's binary_logloss: 0.077985	valid_0's auc: 0.92019
# [70]	valid_0's binary_logloss: 0.0778388	valid_0's auc: 0.92044
# [71]	valid_0's binary_logloss: 0.0777161	valid_0's auc: 0.920703
# [72]	valid_0's binary_logloss: 0.0775388	valid_0's auc: 0.921284
# [73]	valid_0's binary_logloss: 0.0774594	valid_0's auc: 0.921424
# [74]	valid_0's binary_logloss: 0.0776137	valid_0's auc: 0.92149
# [75]	valid_0's binary_logloss: 0.0774872	valid_0's auc: 0.921883
# [76]	valid_0's binary_logloss: 0.0773572	valid_0's auc: 0.922368
# [77]	valid_0's binary_logloss: 0.0771781	valid_0's auc: 0.923564
# [78]	valid_0's binary_logloss: 0.0770659	valid_0's auc: 0.923754
# [79]	valid_0's binary_logloss: 0.0769509	valid_0's auc: 0.923915
# [80]	valid_0's binary_logloss: 0.0768399	valid_0's auc: 0.924049
# [81]	valid_0's binary_logloss: 0.0766641	valid_0's auc: 0.924508
# [82]	valid_0's binary_logloss: 0.0765425	valid_0's auc: 0.92484
# [83]	valid_0's binary_logloss: 0.0764041	valid_0's auc: 0.924959
# [84]	valid_0's binary_logloss: 0.0762696	valid_0's auc: 0.925188
# [85]	valid_0's binary_logloss: 0.07615	valid_0's auc: 0.925324
# [86]	valid_0's binary_logloss: 0.0760383	valid_0's auc: 0.925491
# [87]	valid_0's binary_logloss: 0.0759328	valid_0's auc: 0.925605
# [88]	valid_0's binary_logloss: 0.0758927	valid_0's auc: 0.925907
# [89]	valid_0's binary_logloss: 0.0758025	valid_0's auc: 0.925937
# [90]	valid_0's binary_logloss: 0.0757092	valid_0's auc: 0.926095
# [91]	valid_0's binary_logloss: 0.0754556	valid_0's auc: 0.926717
# [92]	valid_0's binary_logloss: 0.075289	valid_0's auc: 0.927266
# [93]	valid_0's binary_logloss: 0.0751142	valid_0's auc: 0.927993
# [94]	valid_0's binary_logloss: 0.0750068	valid_0's auc: 0.928235
# [95]	valid_0's binary_logloss: 0.0749196	valid_0's auc: 0.928333
# [96]	valid_0's binary_logloss: 0.0747945	valid_0's auc: 0.928591
# [97]	valid_0's binary_logloss: 0.0747006	valid_0's auc: 0.928692
# [98]	valid_0's binary_logloss: 0.0746307	valid_0's auc: 0.928786
# [99]	valid_0's binary_logloss: 0.0745771	valid_0's auc: 0.928836
# [100]	valid_0's binary_logloss: 0.0743707	valid_0's auc: 0.929223
# [101]	valid_0's binary_logloss: 0.0742716	valid_0's auc: 0.929379
# [102]	valid_0's binary_logloss: 0.0741612	valid_0's auc: 0.929594
# [103]	valid_0's binary_logloss: 0.0740803	valid_0's auc: 0.929714
# [104]	valid_0's binary_logloss: 0.0739692	valid_0's auc: 0.929854
# [105]	valid_0's binary_logloss: 0.0738866	valid_0's auc: 0.929923
# [106]	valid_0's binary_logloss: 0.0738243	valid_0's auc: 0.930004
# [107]	valid_0's binary_logloss: 0.0737321	valid_0's auc: 0.930189
# [108]	valid_0's binary_logloss: 0.0736271	valid_0's auc: 0.930301
# [109]	valid_0's binary_logloss: 0.0735501	valid_0's auc: 0.930362
# [110]	valid_0's binary_logloss: 0.0734483	valid_0's auc: 0.930748
# [111]	valid_0's binary_logloss: 0.0733484	valid_0's auc: 0.930787
# [112]	valid_0's binary_logloss: 0.0732584	valid_0's auc: 0.931009
# [113]	valid_0's binary_logloss: 0.0731687	valid_0's auc: 0.931173
# [114]	valid_0's binary_logloss: 0.0730946	valid_0's auc: 0.931277
# [115]	valid_0's binary_logloss: 0.0730113	valid_0's auc: 0.931468
# [116]	valid_0's binary_logloss: 0.072919	valid_0's auc: 0.93159
# [117]	valid_0's binary_logloss: 0.0728735	valid_0's auc: 0.931619
# [118]	valid_0's binary_logloss: 0.0728064	valid_0's auc: 0.931687
# [119]	valid_0's binary_logloss: 0.0727231	valid_0's auc: 0.931835
# [120]	valid_0's binary_logloss: 0.0726456	valid_0's auc: 0.931912
# [121]	valid_0's binary_logloss: 0.0725436	valid_0's auc: 0.931976
# [122]	valid_0's binary_logloss: 0.0724702	valid_0's auc: 0.932056
# [123]	valid_0's binary_logloss: 0.0724241	valid_0's auc: 0.93207
# [124]	valid_0's binary_logloss: 0.0722824	valid_0's auc: 0.932349
# [125]	valid_0's binary_logloss: 0.0722176	valid_0's auc: 0.932401
# [126]	valid_0's binary_logloss: 0.0721112	valid_0's auc: 0.932536
# [127]	valid_0's binary_logloss: 0.072051	valid_0's auc: 0.932618
# [128]	valid_0's binary_logloss: 0.0720153	valid_0's auc: 0.932641
# [129]	valid_0's binary_logloss: 0.0719783	valid_0's auc: 0.932645
# [130]	valid_0's binary_logloss: 0.0718743	valid_0's auc: 0.932968
# [131]	valid_0's binary_logloss: 0.071801	valid_0's auc: 0.933089
# [132]	valid_0's binary_logloss: 0.0717175	valid_0's auc: 0.933213
# [133]	valid_0's binary_logloss: 0.0716047	valid_0's auc: 0.933368
# [134]	valid_0's binary_logloss: 0.0715488	valid_0's auc: 0.93342
# [135]	valid_0's binary_logloss: 0.0714861	valid_0's auc: 0.933526
# [136]	valid_0's binary_logloss: 0.0714575	valid_0's auc: 0.933577
# [137]	valid_0's binary_logloss: 0.0714308	valid_0's auc: 0.933595
# [138]	valid_0's binary_logloss: 0.0713612	valid_0's auc: 0.933704
# [139]	valid_0's binary_logloss: 0.0713276	valid_0's auc: 0.933759
# [140]	valid_0's binary_logloss: 0.0712707	valid_0's auc: 0.933875
# [141]	valid_0's binary_logloss: 0.0712596	valid_0's auc: 0.933856
# [142]	valid_0's binary_logloss: 0.0711681	valid_0's auc: 0.934093
# [143]	valid_0's binary_logloss: 0.0711139	valid_0's auc: 0.93414
# [144]	valid_0's binary_logloss: 0.0709875	valid_0's auc: 0.934463
# [145]	valid_0's binary_logloss: 0.0709619	valid_0's auc: 0.934559
# [146]	valid_0's binary_logloss: 0.0708361	valid_0's auc: 0.934794
# [147]	valid_0's binary_logloss: 0.0707465	valid_0's auc: 0.935094
# [148]	valid_0's binary_logloss: 0.0706927	valid_0's auc: 0.935395
# [149]	valid_0's binary_logloss: 0.0706397	valid_0's auc: 0.935453
# [150]	valid_0's binary_logloss: 0.0705613	valid_0's auc: 0.935553
# [151]	valid_0's binary_logloss: 0.0704212	valid_0's auc: 0.936106
# [152]	valid_0's binary_logloss: 0.070244	valid_0's auc: 0.936567
# [153]	valid_0's binary_logloss: 0.0701619	valid_0's auc: 0.936741
# [154]	valid_0's binary_logloss: 0.0700199	valid_0's auc: 0.937071
# [155]	valid_0's binary_logloss: 0.069985	valid_0's auc: 0.937109
# [156]	valid_0's binary_logloss: 0.0699512	valid_0's auc: 0.937121
# [157]	valid_0's binary_logloss: 0.0699298	valid_0's auc: 0.937118
# [158]	valid_0's binary_logloss: 0.0699076	valid_0's auc: 0.937132
# [159]	valid_0's binary_logloss: 0.0698659	valid_0's auc: 0.937172
# [160]	valid_0's binary_logloss: 0.0698205	valid_0's auc: 0.93719
# [161]	valid_0's binary_logloss: 0.0697261	valid_0's auc: 0.937443
# [162]	valid_0's binary_logloss: 0.0696702	valid_0's auc: 0.937476
# [163]	valid_0's binary_logloss: 0.0696277	valid_0's auc: 0.937627
# [164]	valid_0's binary_logloss: 0.0695846	valid_0's auc: 0.93767
# [165]	valid_0's binary_logloss: 0.0695072	valid_0's auc: 0.937771
# [166]	valid_0's binary_logloss: 0.0694502	valid_0's auc: 0.937824
# [167]	valid_0's binary_logloss: 0.0693899	valid_0's auc: 0.937912
# [168]	valid_0's binary_logloss: 0.0693454	valid_0's auc: 0.938038
# [169]	valid_0's binary_logloss: 0.0693061	valid_0's auc: 0.938047
# [170]	valid_0's binary_logloss: 0.0692411	valid_0's auc: 0.938076
# [171]	valid_0's binary_logloss: 0.0692114	valid_0's auc: 0.938093
# [172]	valid_0's binary_logloss: 0.0691631	valid_0's auc: 0.938159
# [173]	valid_0's binary_logloss: 0.0690922	valid_0's auc: 0.938299
# [174]	valid_0's binary_logloss: 0.0690053	valid_0's auc: 0.938425
# [175]	valid_0's binary_logloss: 0.0689956	valid_0's auc: 0.938414
# [176]	valid_0's binary_logloss: 0.0689752	valid_0's auc: 0.938421
# [177]	valid_0's binary_logloss: 0.068913	valid_0's auc: 0.938501
# [178]	valid_0's binary_logloss: 0.0689025	valid_0's auc: 0.938551
# [179]	valid_0's binary_logloss: 0.0688865	valid_0's auc: 0.938577
# [180]	valid_0's binary_logloss: 0.0688614	valid_0's auc: 0.93863
# [181]	valid_0's binary_logloss: 0.0688287	valid_0's auc: 0.93867
# [182]	valid_0's binary_logloss: 0.0687494	valid_0's auc: 0.938772
# [183]	valid_0's binary_logloss: 0.0686965	valid_0's auc: 0.938844
# [184]	valid_0's binary_logloss: 0.0686417	valid_0's auc: 0.938908
# [185]	valid_0's binary_logloss: 0.0685639	valid_0's auc: 0.939049
# [186]	valid_0's binary_logloss: 0.0684916	valid_0's auc: 0.939176
# [187]	valid_0's binary_logloss: 0.068463	valid_0's auc: 0.939281
# [188]	valid_0's binary_logloss: 0.0684523	valid_0's auc: 0.939296
# [189]	valid_0's binary_logloss: 0.0684035	valid_0's auc: 0.939363
# [190]	valid_0's binary_logloss: 0.0683403	valid_0's auc: 0.939447
# [191]	valid_0's binary_logloss: 0.0682778	valid_0's auc: 0.939617
# [192]	valid_0's binary_logloss: 0.0682143	valid_0's auc: 0.939839
# [193]	valid_0's binary_logloss: 0.0681438	valid_0's auc: 0.939943
# [194]	valid_0's binary_logloss: 0.06811	valid_0's auc: 0.940034
# [195]	valid_0's binary_logloss: 0.0681431	valid_0's auc: 0.940062
# [196]	valid_0's binary_logloss: 0.0681246	valid_0's auc: 0.94007
# [197]	valid_0's binary_logloss: 0.0680876	valid_0's auc: 0.940074
# [198]	valid_0's binary_logloss: 0.0680234	valid_0's auc: 0.940165
# [199]	valid_0's binary_logloss: 0.0679418	valid_0's auc: 0.940394
# [200]	valid_0's binary_logloss: 0.0679157	valid_0's auc: 0.940449
# [201]	valid_0's binary_logloss: 0.0678538	valid_0's auc: 0.9405
# [202]	valid_0's binary_logloss: 0.0678186	valid_0's auc: 0.940538
# [203]	valid_0's binary_logloss: 0.0677868	valid_0's auc: 0.940633
# [204]	valid_0's binary_logloss: 0.0677302	valid_0's auc: 0.940663
# [205]	valid_0's binary_logloss: 0.0676735	valid_0's auc: 0.940704
# [206]	valid_0's binary_logloss: 0.0676166	valid_0's auc: 0.940788
# [207]	valid_0's binary_logloss: 0.0676057	valid_0's auc: 0.940778
# [208]	valid_0's binary_logloss: 0.0674924	valid_0's auc: 0.941228
# [209]	valid_0's binary_logloss: 0.0674461	valid_0's auc: 0.941269
# [210]	valid_0's binary_logloss: 0.0673878	valid_0's auc: 0.941314
# [211]	valid_0's binary_logloss: 0.0673289	valid_0's auc: 0.941425
# [212]	valid_0's binary_logloss: 0.067299	valid_0's auc: 0.94144
# [213]	valid_0's binary_logloss: 0.0672562	valid_0's auc: 0.941486
# [214]	valid_0's binary_logloss: 0.0672338	valid_0's auc: 0.941509
# [215]	valid_0's binary_logloss: 0.0671952	valid_0's auc: 0.941526
# [216]	valid_0's binary_logloss: 0.0671862	valid_0's auc: 0.941522
# [217]	valid_0's binary_logloss: 0.0671241	valid_0's auc: 0.941572
# [218]	valid_0's binary_logloss: 0.0670767	valid_0's auc: 0.941612
# [219]	valid_0's binary_logloss: 0.0670424	valid_0's auc: 0.941726
# [220]	valid_0's binary_logloss: 0.0669668	valid_0's auc: 0.941879
# [221]	valid_0's binary_logloss: 0.066957	valid_0's auc: 0.941916
# [222]	valid_0's binary_logloss: 0.0668543	valid_0's auc: 0.942072
# [223]	valid_0's binary_logloss: 0.0668425	valid_0's auc: 0.94208
# [224]	valid_0's binary_logloss: 0.0667733	valid_0's auc: 0.942155
# [225]	valid_0's binary_logloss: 0.0667495	valid_0's auc: 0.942173
# [226]	valid_0's binary_logloss: 0.0667256	valid_0's auc: 0.942204
# [227]	valid_0's binary_logloss: 0.0667051	valid_0's auc: 0.942221
# [228]	valid_0's binary_logloss: 0.0666697	valid_0's auc: 0.942207
# [229]	valid_0's binary_logloss: 0.0666073	valid_0's auc: 0.942257
# [230]	valid_0's binary_logloss: 0.0665759	valid_0's auc: 0.94226
# [231]	valid_0's binary_logloss: 0.0665335	valid_0's auc: 0.942291
# [232]	valid_0's binary_logloss: 0.0664703	valid_0's auc: 0.942365
# [233]	valid_0's binary_logloss: 0.0664419	valid_0's auc: 0.942378
# [234]	valid_0's binary_logloss: 0.0663432	valid_0's auc: 0.942585
# [235]	valid_0's binary_logloss: 0.0663009	valid_0's auc: 0.942673
# [236]	valid_0's binary_logloss: 0.0662554	valid_0's auc: 0.942726
# [237]	valid_0's binary_logloss: 0.0662157	valid_0's auc: 0.942891
# [238]	valid_0's binary_logloss: 0.066154	valid_0's auc: 0.942945
# [239]	valid_0's binary_logloss: 0.0661148	valid_0's auc: 0.942974
# [240]	valid_0's binary_logloss: 0.0660758	valid_0's auc: 0.943136
# [241]	valid_0's binary_logloss: 0.0660336	valid_0's auc: 0.943165
# [242]	valid_0's binary_logloss: 0.0659924	valid_0's auc: 0.943269
# [243]	valid_0's binary_logloss: 0.0659695	valid_0's auc: 0.943281
# [244]	valid_0's binary_logloss: 0.0659458	valid_0's auc: 0.943305
# [245]	valid_0's binary_logloss: 0.0659065	valid_0's auc: 0.943351
# [246]	valid_0's binary_logloss: 0.0658691	valid_0's auc: 0.943513
# [247]	valid_0's binary_logloss: 0.0658379	valid_0's auc: 0.943544
# [248]	valid_0's binary_logloss: 0.0658259	valid_0's auc: 0.94356
# [249]	valid_0's binary_logloss: 0.0657523	valid_0's auc: 0.943816
# [250]	valid_0's binary_logloss: 0.0657445	valid_0's auc: 0.943825
# [251]	valid_0's binary_logloss: 0.0656884	valid_0's auc: 0.943876
# [252]	valid_0's binary_logloss: 0.0656846	valid_0's auc: 0.943892
# [253]	valid_0's binary_logloss: 0.0656604	valid_0's auc: 0.943896
# [254]	valid_0's binary_logloss: 0.065631	valid_0's auc: 0.943942
# [255]	valid_0's binary_logloss: 0.0656004	valid_0's auc: 0.943998
# [256]	valid_0's binary_logloss: 0.0655681	valid_0's auc: 0.944044
# [257]	valid_0's binary_logloss: 0.0655494	valid_0's auc: 0.944069
# [258]	valid_0's binary_logloss: 0.0655268	valid_0's auc: 0.944084
# [259]	valid_0's binary_logloss: 0.0655126	valid_0's auc: 0.944091
# [260]	valid_0's binary_logloss: 0.0654955	valid_0's auc: 0.944159
# [261]	valid_0's binary_logloss: 0.0654781	valid_0's auc: 0.94416
# [262]	valid_0's binary_logloss: 0.0654342	valid_0's auc: 0.944251
# [263]	valid_0's binary_logloss: 0.0654088	valid_0's auc: 0.944327
# [264]	valid_0's binary_logloss: 0.0653867	valid_0's auc: 0.944347
# [265]	valid_0's binary_logloss: 0.0653679	valid_0's auc: 0.944362
# [266]	valid_0's binary_logloss: 0.065362	valid_0's auc: 0.94437
# [267]	valid_0's binary_logloss: 0.0653656	valid_0's auc: 0.944393
# [268]	valid_0's binary_logloss: 0.0653677	valid_0's auc: 0.944386
# [269]	valid_0's binary_logloss: 0.0653355	valid_0's auc: 0.944423
# [270]	valid_0's binary_logloss: 0.0653246	valid_0's auc: 0.9444
# [271]	valid_0's binary_logloss: 0.0653026	valid_0's auc: 0.944388
# [272]	valid_0's binary_logloss: 0.0652691	valid_0's auc: 0.944415
# [273]	valid_0's binary_logloss: 0.0652371	valid_0's auc: 0.944447
# [274]	valid_0's binary_logloss: 0.0652017	valid_0's auc: 0.944479
# [275]	valid_0's binary_logloss: 0.0651196	valid_0's auc: 0.944772
# [276]	valid_0's binary_logloss: 0.0650569	valid_0's auc: 0.944938
# [277]	valid_0's binary_logloss: 0.0650316	valid_0's auc: 0.944968
# [278]	valid_0's binary_logloss: 0.0650191	valid_0's auc: 0.944993
# [279]	valid_0's binary_logloss: 0.0649679	valid_0's auc: 0.945041
# [280]	valid_0's binary_logloss: 0.0649209	valid_0's auc: 0.945088
# [281]	valid_0's binary_logloss: 0.0648869	valid_0's auc: 0.945126
# [282]	valid_0's binary_logloss: 0.0648675	valid_0's auc: 0.945147
# [283]	valid_0's binary_logloss: 0.06483	valid_0's auc: 0.945171
# [284]	valid_0's binary_logloss: 0.0647951	valid_0's auc: 0.945199
# [285]	valid_0's binary_logloss: 0.0647736	valid_0's auc: 0.945229
# [286]	valid_0's binary_logloss: 0.0647584	valid_0's auc: 0.94523
# [287]	valid_0's binary_logloss: 0.0647261	valid_0's auc: 0.945258
# [288]	valid_0's binary_logloss: 0.064654	valid_0's auc: 0.945327
# [289]	valid_0's binary_logloss: 0.0646049	valid_0's auc: 0.945392
# [290]	valid_0's binary_logloss: 0.0645701	valid_0's auc: 0.945433
# [291]	valid_0's binary_logloss: 0.0645216	valid_0's auc: 0.945554
# [292]	valid_0's binary_logloss: 0.064508	valid_0's auc: 0.945582
# [293]	valid_0's binary_logloss: 0.0644639	valid_0's auc: 0.945601
# [294]	valid_0's binary_logloss: 0.0644413	valid_0's auc: 0.945627
# [295]	valid_0's binary_logloss: 0.0644212	valid_0's auc: 0.945628
# [296]	valid_0's binary_logloss: 0.0643988	valid_0's auc: 0.945645
# [297]	valid_0's binary_logloss: 0.0643658	valid_0's auc: 0.945664
# [298]	valid_0's binary_logloss: 0.0643376	valid_0's auc: 0.945698
# [299]	valid_0's binary_logloss: 0.0643154	valid_0's auc: 0.94572
# [300]	valid_0's binary_logloss: 0.0643013	valid_0's auc: 0.945734
# [301]	valid_0's binary_logloss: 0.0642682	valid_0's auc: 0.945839
# [302]	valid_0's binary_logloss: 0.0642466	valid_0's auc: 0.945834
# [303]	valid_0's binary_logloss: 0.0642024	valid_0's auc: 0.945868
# [304]	valid_0's binary_logloss: 0.0641623	valid_0's auc: 0.946007
# [305]	valid_0's binary_logloss: 0.0641592	valid_0's auc: 0.945998
# [306]	valid_0's binary_logloss: 0.0640641	valid_0's auc: 0.946219
# [307]	valid_0's binary_logloss: 0.0639669	valid_0's auc: 0.946396
# [308]	valid_0's binary_logloss: 0.063942	valid_0's auc: 0.946409
# [309]	valid_0's binary_logloss: 0.0638914	valid_0's auc: 0.946556
# [310]	valid_0's binary_logloss: 0.0638479	valid_0's auc: 0.946637
# [311]	valid_0's binary_logloss: 0.0638268	valid_0's auc: 0.946658
# [312]	valid_0's binary_logloss: 0.0638421	valid_0's auc: 0.946666
# [313]	valid_0's binary_logloss: 0.0637945	valid_0's auc: 0.946689
# [314]	valid_0's binary_logloss: 0.06376	valid_0's auc: 0.946731
# [315]	valid_0's binary_logloss: 0.0637497	valid_0's auc: 0.946734
# [316]	valid_0's binary_logloss: 0.0637273	valid_0's auc: 0.946737
# [317]	valid_0's binary_logloss: 0.063662	valid_0's auc: 0.946814
# [318]	valid_0's binary_logloss: 0.0636477	valid_0's auc: 0.946803
# [319]	valid_0's binary_logloss: 0.0636217	valid_0's auc: 0.946835
# [320]	valid_0's binary_logloss: 0.0635679	valid_0's auc: 0.946937
# [321]	valid_0's binary_logloss: 0.0635358	valid_0's auc: 0.946968
# [322]	valid_0's binary_logloss: 0.0634874	valid_0's auc: 0.947014
# [323]	valid_0's binary_logloss: 0.0634444	valid_0's auc: 0.947054
# [324]	valid_0's binary_logloss: 0.0634273	valid_0's auc: 0.947072
# [325]	valid_0's binary_logloss: 0.0634165	valid_0's auc: 0.947087
# [326]	valid_0's binary_logloss: 0.063383	valid_0's auc: 0.947141
# [327]	valid_0's binary_logloss: 0.0633651	valid_0's auc: 0.947182
# [328]	valid_0's binary_logloss: 0.0633405	valid_0's auc: 0.947299
# [329]	valid_0's binary_logloss: 0.0632524	valid_0's auc: 0.947483
# [330]	valid_0's binary_logloss: 0.0632233	valid_0's auc: 0.947494
# [331]	valid_0's binary_logloss: 0.0631148	valid_0's auc: 0.947951
# [332]	valid_0's binary_logloss: 0.0632568	valid_0's auc: 0.948012
# [333]	valid_0's binary_logloss: 0.0631883	valid_0's auc: 0.948032
# [334]	valid_0's binary_logloss: 0.0631373	valid_0's auc: 0.94809
# [335]	valid_0's binary_logloss: 0.0631092	valid_0's auc: 0.948142
# [336]	valid_0's binary_logloss: 0.0630674	valid_0's auc: 0.948205
# [337]	valid_0's binary_logloss: 0.0630468	valid_0's auc: 0.948206
# [338]	valid_0's binary_logloss: 0.0629484	valid_0's auc: 0.948469
# [339]	valid_0's binary_logloss: 0.0629215	valid_0's auc: 0.948488
# [340]	valid_0's binary_logloss: 0.0628533	valid_0's auc: 0.948638
# [341]	valid_0's binary_logloss: 0.0628724	valid_0's auc: 0.948639
# [342]	valid_0's binary_logloss: 0.0628204	valid_0's auc: 0.948749
# [343]	valid_0's binary_logloss: 0.0628004	valid_0's auc: 0.94871
# [344]	valid_0's binary_logloss: 0.0627492	valid_0's auc: 0.948917
# [345]	valid_0's binary_logloss: 0.0627327	valid_0's auc: 0.948939
# [346]	valid_0's binary_logloss: 0.0627126	valid_0's auc: 0.94897
# [347]	valid_0's binary_logloss: 0.0626853	valid_0's auc: 0.948957
# [348]	valid_0's binary_logloss: 0.0626487	valid_0's auc: 0.949
# [349]	valid_0's binary_logloss: 0.0626129	valid_0's auc: 0.94904
# [350]	valid_0's binary_logloss: 0.0625843	valid_0's auc: 0.949076
# [351]	valid_0's binary_logloss: 0.0625537	valid_0's auc: 0.949085
# [352]	valid_0's binary_logloss: 0.0625413	valid_0's auc: 0.949085
# [353]	valid_0's binary_logloss: 0.0624919	valid_0's auc: 0.949221
# [354]	valid_0's binary_logloss: 0.0624701	valid_0's auc: 0.949236
# [355]	valid_0's binary_logloss: 0.0624414	valid_0's auc: 0.949243
# [356]	valid_0's binary_logloss: 0.0624137	valid_0's auc: 0.949268
# [357]	valid_0's binary_logloss: 0.0624003	valid_0's auc: 0.949284
# [358]	valid_0's binary_logloss: 0.0623638	valid_0's auc: 0.949364
# [359]	valid_0's binary_logloss: 0.0623284	valid_0's auc: 0.949403
# [360]	valid_0's binary_logloss: 0.0623029	valid_0's auc: 0.94943
# [361]	valid_0's binary_logloss: 0.0622639	valid_0's auc: 0.949439
# [362]	valid_0's binary_logloss: 0.0622549	valid_0's auc: 0.949425
# [363]	valid_0's binary_logloss: 0.0622239	valid_0's auc: 0.949464
# [364]	valid_0's binary_logloss: 0.0622115	valid_0's auc: 0.949499
# [365]	valid_0's binary_logloss: 0.0622006	valid_0's auc: 0.949511
# [366]	valid_0's binary_logloss: 0.0621404	valid_0's auc: 0.94962
# [367]	valid_0's binary_logloss: 0.0620625	valid_0's auc: 0.949674
# [368]	valid_0's binary_logloss: 0.0620496	valid_0's auc: 0.94967
# [369]	valid_0's binary_logloss: 0.0620275	valid_0's auc: 0.949686
# [370]	valid_0's binary_logloss: 0.0620166	valid_0's auc: 0.949703
# [371]	valid_0's binary_logloss: 0.062008	valid_0's auc: 0.949699
# [372]	valid_0's binary_logloss: 0.0619737	valid_0's auc: 0.949728
# [373]	valid_0's binary_logloss: 0.0619372	valid_0's auc: 0.949808
# [374]	valid_0's binary_logloss: 0.061888	valid_0's auc: 0.949919
# [375]	valid_0's binary_logloss: 0.0618741	valid_0's auc: 0.949909
# [376]	valid_0's binary_logloss: 0.0618471	valid_0's auc: 0.949959
# [377]	valid_0's binary_logloss: 0.061822	valid_0's auc: 0.950001
# [378]	valid_0's binary_logloss: 0.0617913	valid_0's auc: 0.950017
# [379]	valid_0's binary_logloss: 0.0617797	valid_0's auc: 0.950041
# [380]	valid_0's binary_logloss: 0.0617621	valid_0's auc: 0.950063
# [381]	valid_0's binary_logloss: 0.06173	valid_0's auc: 0.950085
# [382]	valid_0's binary_logloss: 0.0617163	valid_0's auc: 0.950086
# [383]	valid_0's binary_logloss: 0.0617014	valid_0's auc: 0.950096
# [384]	valid_0's binary_logloss: 0.0616812	valid_0's auc: 0.950134
# [385]	valid_0's binary_logloss: 0.0616641	valid_0's auc: 0.950136
# [386]	valid_0's binary_logloss: 0.0616407	valid_0's auc: 0.950155
# [387]	valid_0's binary_logloss: 0.0616344	valid_0's auc: 0.950148
# [388]	valid_0's binary_logloss: 0.0615894	valid_0's auc: 0.950208
# [389]	valid_0's binary_logloss: 0.0615645	valid_0's auc: 0.950225
# [390]	valid_0's binary_logloss: 0.0615375	valid_0's auc: 0.950264
# [391]	valid_0's binary_logloss: 0.0615167	valid_0's auc: 0.950277
# [392]	valid_0's binary_logloss: 0.0615063	valid_0's auc: 0.95028
# [393]	valid_0's binary_logloss: 0.0614811	valid_0's auc: 0.950313
# [394]	valid_0's binary_logloss: 0.0614584	valid_0's auc: 0.950321
# [395]	valid_0's binary_logloss: 0.0614474	valid_0's auc: 0.950331
# [396]	valid_0's binary_logloss: 0.0614266	valid_0's auc: 0.950343
# [397]	valid_0's binary_logloss: 0.0614004	valid_0's auc: 0.950368
# [398]	valid_0's binary_logloss: 0.0613971	valid_0's auc: 0.950378
# [399]	valid_0's binary_logloss: 0.0613823	valid_0's auc: 0.950392
# [400]	valid_0's binary_logloss: 0.0613503	valid_0's auc: 0.950445
# [401]	valid_0's binary_logloss: 0.0613486	valid_0's auc: 0.95046
# [402]	valid_0's binary_logloss: 0.0613346	valid_0's auc: 0.950489
# [403]	valid_0's binary_logloss: 0.0612899	valid_0's auc: 0.95056
# [404]	valid_0's binary_logloss: 0.0612712	valid_0's auc: 0.950588
# [405]	valid_0's binary_logloss: 0.0612498	valid_0's auc: 0.950612
# [406]	valid_0's binary_logloss: 0.0612393	valid_0's auc: 0.950626
# [407]	valid_0's binary_logloss: 0.0612081	valid_0's auc: 0.950652
# [408]	valid_0's binary_logloss: 0.06119	valid_0's auc: 0.950679
# [409]	valid_0's binary_logloss: 0.0611505	valid_0's auc: 0.950713
# [410]	valid_0's binary_logloss: 0.0611379	valid_0's auc: 0.950715
# [411]	valid_0's binary_logloss: 0.0610609	valid_0's auc: 0.950868
# [412]	valid_0's binary_logloss: 0.0610421	valid_0's auc: 0.950877
# [413]	valid_0's binary_logloss: 0.0610246	valid_0's auc: 0.950951
# [414]	valid_0's binary_logloss: 0.061011	valid_0's auc: 0.950993
# [415]	valid_0's binary_logloss: 0.0609855	valid_0's auc: 0.951001
# [416]	valid_0's binary_logloss: 0.0609727	valid_0's auc: 0.951011
# [417]	valid_0's binary_logloss: 0.060954	valid_0's auc: 0.951034
# [418]	valid_0's binary_logloss: 0.0609248	valid_0's auc: 0.951043
# [419]	valid_0's binary_logloss: 0.0609157	valid_0's auc: 0.951073
# [420]	valid_0's binary_logloss: 0.0609012	valid_0's auc: 0.951077
# [421]	valid_0's binary_logloss: 0.0609055	valid_0's auc: 0.951044
# [422]	valid_0's binary_logloss: 0.0608883	valid_0's auc: 0.951111
# [423]	valid_0's binary_logloss: 0.0608598	valid_0's auc: 0.951142
# [424]	valid_0's binary_logloss: 0.060834	valid_0's auc: 0.951178
# [425]	valid_0's binary_logloss: 0.0608005	valid_0's auc: 0.951201
# [426]	valid_0's binary_logloss: 0.0607833	valid_0's auc: 0.951218
# [427]	valid_0's binary_logloss: 0.060776	valid_0's auc: 0.951194
# [428]	valid_0's binary_logloss: 0.0607476	valid_0's auc: 0.95119
# [429]	valid_0's binary_logloss: 0.0607379	valid_0's auc: 0.95118
# [430]	valid_0's binary_logloss: 0.0607083	valid_0's auc: 0.951214
# [431]	valid_0's binary_logloss: 0.0606977	valid_0's auc: 0.951223
# [432]	valid_0's binary_logloss: 0.0606948	valid_0's auc: 0.951218
# [433]	valid_0's binary_logloss: 0.0606829	valid_0's auc: 0.951205
# [434]	valid_0's binary_logloss: 0.0606371	valid_0's auc: 0.951271
# [435]	valid_0's binary_logloss: 0.0606017	valid_0's auc: 0.951336
# [436]	valid_0's binary_logloss: 0.0605772	valid_0's auc: 0.951385
# [437]	valid_0's binary_logloss: 0.0605304	valid_0's auc: 0.951463
# [438]	valid_0's binary_logloss: 0.0605184	valid_0's auc: 0.951469
# [439]	valid_0's binary_logloss: 0.0604965	valid_0's auc: 0.951492
# [440]	valid_0's binary_logloss: 0.0604856	valid_0's auc: 0.951502
# [441]	valid_0's binary_logloss: 0.0604726	valid_0's auc: 0.951523
# [442]	valid_0's binary_logloss: 0.0604579	valid_0's auc: 0.951536
# [443]	valid_0's binary_logloss: 0.0604506	valid_0's auc: 0.951541
# [444]	valid_0's binary_logloss: 0.0604157	valid_0's auc: 0.951572
# [445]	valid_0's binary_logloss: 0.0603897	valid_0's auc: 0.951602
# [446]	valid_0's binary_logloss: 0.0603451	valid_0's auc: 0.951648
# [447]	valid_0's binary_logloss: 0.0603135	valid_0's auc: 0.951711
# [448]	valid_0's binary_logloss: 0.0603032	valid_0's auc: 0.951731
# [449]	valid_0's binary_logloss: 0.0602863	valid_0's auc: 0.95176
# [450]	valid_0's binary_logloss: 0.0602814	valid_0's auc: 0.951763
# [451]	valid_0's binary_logloss: 0.0602509	valid_0's auc: 0.951778
# [452]	valid_0's binary_logloss: 0.060203	valid_0's auc: 0.951824
# [453]	valid_0's binary_logloss: 0.0601863	valid_0's auc: 0.951856
# [454]	valid_0's binary_logloss: 0.0601514	valid_0's auc: 0.951912
# [455]	valid_0's binary_logloss: 0.0601392	valid_0's auc: 0.951929
# [456]	valid_0's binary_logloss: 0.0601061	valid_0's auc: 0.95196
# [457]	valid_0's binary_logloss: 0.0600774	valid_0's auc: 0.951984
# [458]	valid_0's binary_logloss: 0.0600491	valid_0's auc: 0.95204
# [459]	valid_0's binary_logloss: 0.0600336	valid_0's auc: 0.952035
# [460]	valid_0's binary_logloss: 0.0599923	valid_0's auc: 0.95213
# [461]	valid_0's binary_logloss: 0.0599752	valid_0's auc: 0.952144
# [462]	valid_0's binary_logloss: 0.0599754	valid_0's auc: 0.952143
# [463]	valid_0's binary_logloss: 0.0599596	valid_0's auc: 0.95216
# [464]	valid_0's binary_logloss: 0.0599491	valid_0's auc: 0.952162
# [465]	valid_0's binary_logloss: 0.0599442	valid_0's auc: 0.952162
# [466]	valid_0's binary_logloss: 0.0598977	valid_0's auc: 0.952204
# [467]	valid_0's binary_logloss: 0.0598724	valid_0's auc: 0.952226
# [468]	valid_0's binary_logloss: 0.0598526	valid_0's auc: 0.952257
# [469]	valid_0's binary_logloss: 0.059819	valid_0's auc: 0.952336
# [470]	valid_0's binary_logloss: 0.0597896	valid_0's auc: 0.952362
# [471]	valid_0's binary_logloss: 0.059774	valid_0's auc: 0.952383
# [472]	valid_0's binary_logloss: 0.0597428	valid_0's auc: 0.952422
# [473]	valid_0's binary_logloss: 0.0597272	valid_0's auc: 0.952442
# [474]	valid_0's binary_logloss: 0.0597008	valid_0's auc: 0.95246
# [475]	valid_0's binary_logloss: 0.0596992	valid_0's auc: 0.952429
# [476]	valid_0's binary_logloss: 0.0596838	valid_0's auc: 0.95241
# [477]	valid_0's binary_logloss: 0.0596786	valid_0's auc: 0.952413
# [478]	valid_0's binary_logloss: 0.0596612	valid_0's auc: 0.952425
# [479]	valid_0's binary_logloss: 0.0596608	valid_0's auc: 0.952407
# [480]	valid_0's binary_logloss: 0.0596586	valid_0's auc: 0.952398
# [481]	valid_0's binary_logloss: 0.0596094	valid_0's auc: 0.952529
# [482]	valid_0's binary_logloss: 0.059572	valid_0's auc: 0.952608
# [483]	valid_0's binary_logloss: 0.0595392	valid_0's auc: 0.952661
# [484]	valid_0's binary_logloss: 0.0595269	valid_0's auc: 0.952679
# [485]	valid_0's binary_logloss: 0.0595164	valid_0's auc: 0.952669
# [486]	valid_0's binary_logloss: 0.0594815	valid_0's auc: 0.952736
# [487]	valid_0's binary_logloss: 0.0594654	valid_0's auc: 0.952752
# [488]	valid_0's binary_logloss: 0.0594614	valid_0's auc: 0.952764
# [489]	valid_0's binary_logloss: 0.0594256	valid_0's auc: 0.952799
# [490]	valid_0's binary_logloss: 0.0594	valid_0's auc: 0.95285
# [491]	valid_0's binary_logloss: 0.0593933	valid_0's auc: 0.952852
# [492]	valid_0's binary_logloss: 0.0593772	valid_0's auc: 0.952878
# [493]	valid_0's binary_logloss: 0.0593702	valid_0's auc: 0.952882
# [494]	valid_0's binary_logloss: 0.059353	valid_0's auc: 0.952897
# [495]	valid_0's binary_logloss: 0.0593175	valid_0's auc: 0.952948
# [496]	valid_0's binary_logloss: 0.0592923	valid_0's auc: 0.952956
# [497]	valid_0's binary_logloss: 0.0592893	valid_0's auc: 0.952966
# [498]	valid_0's binary_logloss: 0.0592371	valid_0's auc: 0.953058
# [499]	valid_0's binary_logloss: 0.0592235	valid_0's auc: 0.953092
# [500]	valid_0's binary_logloss: 0.0592016	valid_0's auc: 0.953147
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's binary_logloss: 0.0592016	valid_0's auc: 0.953147
# ROC AUC : 0.9531
# Wall time: 3min 9s

# %% [markdown]
# # 6. Make Submission

# %%
y_pred = lgbm_clf.predict_proba(X_test)[:,1]

sample_submission['isFraud'] = y_pred
sample_submission.to_csv('v011_lightgbm.csv', index=False)

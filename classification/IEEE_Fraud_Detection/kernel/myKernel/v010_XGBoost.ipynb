# %% [markdown]
# # 1. Load Libraries

# %%
# https://github.com/J911/slack-notifier
from SlackNotifier.notifier import SlackNotifier

api_url = 'https://hooks.slack.com/services/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'
channel = '#ieee-cis-fraud-detection'
sn = SlackNotifier(api_url, channel)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.preprocessing import LabelEncoder

from sklearn.model_selection import train_test_split

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score

import warnings
warnings.filterwarnings('ignore')

import os
print(os.listdir('../../input'))
# Out:
# ['sample_submission.csv', 'test_identity.csv', 'test_transaction.csv', 'train_identity.csv', 'train_transaction.csv']

# %% [markdown]
# # 2. Prepare Data

# %% [markdown]
# ## 2.1 Load Datasets

# %%
df_train_t = pd.read_csv('../../input/train_transaction.csv', index_col='TransactionID')
df_train_i = pd.read_csv('../../input/train_identity.csv', index_col='TransactionID')
df_test_t = pd.read_csv('../../input/test_transaction.csv', index_col='TransactionID')
df_test_i = pd.read_csv('../../input/test_identity.csv', index_col='TransactionID')
sample_submission = pd.read_csv('../../input/sample_submission.csv')

print('train_transaction의 shape : ', df_train_t.shape)
print('train_identity의 shape : ', df_train_i.shape)
print('test_transaction의 shape : ', df_test_t.shape)
print('test_transaction의 shape : ', df_test_i.shape)
# Out:
# train_transaction의 shape :  (590540, 393)
# train_identity의 shape :  (144233, 40)
# test_transaction의 shape :  (506691, 392)
# test_transaction의 shape :  (141907, 40)

# %% [markdown]
# ## 2.2 Merge Datasets

# %%
df_train = df_train_t.merge(df_train_i, 
                            how='left', 
                            left_index=True, 
                            right_index=True)
df_test = df_test_t.merge(df_test_i, 
                          how='left', 
                          left_index=True, 
                          right_index=True)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 590540 entries, 2987000 to 3577539
# Columns: 433 entries, isFraud to DeviceInfo
# dtypes: float64(399), int64(3), object(31)
# memory usage: 1.9+ GB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 506691 entries, 3663549 to 4170239
# Columns: 432 entries, TransactionDT to DeviceInfo
# dtypes: float64(399), int64(2), object(31)
# memory usage: 1.7+ GB

# %% [markdown]
# ## 2.3 Reduce Memory Usage

# %%
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2    
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)    
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

# %%
df_train = reduce_mem_usage(df_train)
df_test = reduce_mem_usage(df_test)
# Out:
# Mem. usage decreased to 668.22 Mb (66.2% reduction)
# Mem. usage decreased to 583.43 Mb (65.6% reduction)

# %% [markdown]
# ## 2.4 Divide Features by Categorical and Numerical

# %% [markdown]
# ### 2.4.1 Categorical Features

# %%
# cat_col_t : categorical columns in transaction dataset
cat_col_t = ['ProductCD','addr1','addr2', 'P_emaildomain', 'R_emaildomain', 'TransactionDT']
cat_col_t.extend(['card' + str(x) for x in range(1,7)]) # card1 ~ card6
cat_col_t.extend(['M' + str(x) for x in range(1,10)]) # M1 ~ M9

# cat_col_i : categorical columns in identity dataset
cat_col_i = ['DeviceType', 'DeviceInfo']
cat_col_i.extend(['id_' + str(x) for x in range(12, 39)]) # id_12 ~ id_38

# cat_col : categorical columns in transaction and identity dataset
cat_col = [*cat_col_t, *cat_col_i]

# %% [markdown]
# ### 2.4.2 Numerical Features

# %%
# num_col_t : numerical columns in transaction dataset
num_col_t = [col for col in list(df_train_t.columns) if col not in [*cat_col_t, 'isFraud']]

# num_col_i : numerical columns in identity dataset
num_col_i = [col for col in list(df_train_i.columns) if col not in cat_col_i]

# num_col : numerical columns in transaction and identity dataset
num_col =[*num_col_t, *num_col_i]

# %% [markdown]
# ### 2.4.3 Transaction Dataset

# %%
print("number of transaction dataset's columns : ", df_train_t.shape[1])
print("cat_col_t's length : ", len(cat_col_t))
print("num_col_t's length : ", len(num_col_t))
print("sum of boths : ", len(cat_col_t) + len(num_col_t))
# Out:
# number of transaction dataset's columns :  393
# cat_col_t's length :  21
# num_col_t's length :  371
# sum of boths :  392

# %% [markdown]
# ### 2.4.4 Identity Dataset

# %%
print("number of transaction dataset's columns : ", df_train_i.shape[1])
print("cat_col_i's length : ", len(cat_col_i))
print("num_col_i's length : ", len(num_col_i))
print("sum of boths : ", len(cat_col_i) + len(num_col_i))
# Out:
# number of transaction dataset's columns :  40
# cat_col_i's length :  29
# num_col_i's length :  11
# sum of boths :  40

# %%
sn.noti('Prepare Data Finished!')

# %% [markdown]
# # 3. Summary of Features

# %% [markdown]
# ## 3.1 Summary of Categorical Features

# %%
def make_cat_summary(df, features) :

    summary = df[features].dtypes.reset_index()
    summary.rename(columns={'index': 'Name', 0: 'Dtype'}, inplace=True)
    summary['DataSets'] = ['transaction' if col in cat_col_t else 'identity' for col in features]
    summary['NullCnt'] = [df[col].isnull().sum() for col in features]
    summary['NullRt'] = [np.round((df[col].isnull().sum())/df.shape[0], 2) for col in features]
    summary['UniqueCnt'] = [df[col].nunique() for col in features]
    Values = []
    for col in features :
        if df[col].nunique() <= 5 :
            val = list(df[col].value_counts().reset_index()['index'])
            val.sort()
            Values.append(', '.join(str(v) for v in val))
        else :
            Values.append('-')    
    summary['Values'] = Values
    summary['MinValue'] = [df.loc[df[col].notnull(), col].min() for col in features]
    summary['MaxValue'] = [df.loc[df[col].notnull(), col].max() for col in features]
    
    return summary

# %%
cat_summary = make_cat_summary(df_train, cat_col)
cat_summary.head()
# Out:
#             Name    Dtype     DataSets  NullCnt  NullRt  UniqueCnt  \
# 0      ProductCD   object  transaction        0    0.00          5
# 1          addr1  float16  transaction    65706    0.11        332
# 2          addr2  float16  transaction    65706    0.11         74
# 3  P_emaildomain   object  transaction    94456    0.16         59
# 4  R_emaildomain   object  transaction   453249    0.77         60
#
#           Values MinValue   MaxValue
# 0  C, H, R, S, W        C          W
# 1              -      100        540
# 2              -       10        102
# 3              -  aim.com  ymail.com
# 4              -  aim.com  ymail.com

# %% [markdown]
# ## 3.2 Summary of Numerical Features

# %%
def make_num_summary(df, features) :
    
    summary = df[features].dtypes.reset_index()
    summary.rename(columns={'index': 'Name', 0: 'Dtype'}, inplace=True)
    summary['DataSets'] = ['transaction' if col in num_col_t else 'identity' for col in features]
    summary['NullCnt'] = [df[col].isnull().sum() for col in features]
    summary['NullRt'] = [np.round((df[col].isnull().sum())/df.shape[0], 2) for col in features]
    summary['MinValue'] = [df.loc[df[col].notnull(), col].min() for col in features]
    summary['Q25'] = [df[col].quantile([0.25]).values[0] for col in features]
    summary['Q50'] = [df[col].quantile([0.50]).values[0] for col in features]
    summary['Q75'] = [df[col].quantile([0.75]).values[0] for col in features]
    summary['MaxValue'] = [df.loc[df[col].notnull(), col].max() for col in features]
    summary['Mean'] = [df.loc[df[col].notnull(), col].mean() for col in features]
    summary['Std'] = [df.loc[df[col].notnull(), col].std() for col in features]

    return summary

# %%
num_summary = make_num_summary(df_train, num_col)
num_summary.head()
# Out:
#              Name    Dtype     DataSets  NullCnt  NullRt  MinValue      Q25  \
# 0  TransactionAmt  float16  transaction        0    0.00  0.250977  43.3125
# 1           dist1  float16  transaction   352271    0.60  0.000000   3.0000
# 2           dist2  float16  transaction   552913    0.94  0.000000   7.0000
# 3              C1  float16  transaction        0    0.00  0.000000   1.0000
# 4              C2  float16  transaction        0    0.00  0.000000   1.0000
#
#      Q50    Q75  MaxValue  Mean  Std
# 0  68.75  125.0   31936.0   NaN  NaN
# 1   8.00   24.0   10288.0   NaN  NaN
# 2  37.00  206.0   11624.0   inf  inf
# 3   1.00    3.0    4684.0   NaN  NaN
# 4   1.00    3.0    5692.0   NaN  NaN

# %%
sn.noti('Summary Finished')

# %% [markdown]
# # 4. Feature Engineering

# %% [markdown]
# ## 4.1 Define Functions

# %%
def value_acc_freq(df, col) :
        
    df_vc = df[col].value_counts().reset_index()
    df_vc.rename(columns={'index': 'value', col: 'cnt'}, inplace=True)
    df_vc['accCntRt'] = df_vc['cnt'].cumsum() / len(df[df[col].notnull()])
    
    return df_vc

# %%
def replace_to_others(df, col, rate=None, cnt=None) :
    
    df_vc = df[col].value_counts().reset_index()
    df_vc.rename(columns={'index': 'value', col: 'cnt'}, inplace=True)
    df_vc['accCntRt'] = df_vc['cnt'].cumsum() / len(df[df[col].notnull()])
    target_list = []
    
    if rate != None :
        target_list = list(df_vc[df_vc['accCntRt'] >= float(rate)]['value'])
    if cnt != None :
        target_list = list(df_vc[df_vc['cnt'] < int(10)]['value'])
        
    dataType = str(df_vc['value'].values.dtype)
    replace_value = 'OTHERS'
    if dataType.find('int') == 0 :
        replace_value = int(99999)
    elif dataType.find('float') == 0 :
        replace_value = float(99999)
    
    df.loc[df[col].isin(target_list), col] = replace_value

# %% [markdown]
# ## 4.2 Feature Engineering for Categorical Features

# %%
def cat_feature_engineering(df) :
    # addr1
    replace_to_others(df, 'addr1', rate=0.95)

    # addr2
    replace_to_others(df, 'addr2', cnt=10)

    # P_emaildomain
    df.loc[df['P_emaildomain'].str.contains('gmail', na=False), 'P_emaildomain'] = 'GMAIL'
    df.loc[df['P_emaildomain'].str.contains('yahoo', na=False), 'P_emaildomain'] = 'YAHOO'
    df.loc[df['P_emaildomain'].str.contains('hotmail', na=False), 'P_emaildomain'] = 'HOTMAIL'
    df.loc[df['P_emaildomain'].str.contains('live', na=False), 'P_emaildomain'] = 'LIVE'
    df.loc[df['P_emaildomain'].str.contains('netzero', na=False), 'P_emaildomain'] = 'NETZERO'
    df.loc[df['P_emaildomain'].str.contains('outlook', na=False), 'P_emaildomain'] = 'OUTLOOK'
    replace_to_others(df, 'P_emaildomain', cnt=250)

    # R_emaildomain
    df.loc[df['R_emaildomain'].str.contains('gmail', na=False), 'R_emaildomain'] = 'GMAIL'
    df.loc[df['R_emaildomain'].str.contains('yahoo', na=False), 'R_emaildomain'] = 'YAHOO'
    df.loc[df['R_emaildomain'].str.contains('hotmail', na=False), 'R_emaildomain'] = 'HOTMAIL'
    df.loc[df['R_emaildomain'].str.contains('live', na=False), 'R_emaildomain'] = 'LIVE'
    df.loc[df['R_emaildomain'].str.contains('netzero', na=False), 'R_emaildomain'] = 'NETZERO'
    df.loc[df['R_emaildomain'].str.contains('outlook', na=False), 'R_emaildomain'] = 'OUTLOOK'
    replace_to_others(df, 'R_emaildomain', cnt=80)

    # TransactionDT
    # Reference : https://www.kaggle.com/shkim4738/extensive-eda-and-modeling-xgb-hyperopt
    import datetime

    START_DATE = '2017-12-01'
    startdate = datetime.datetime.strptime(START_DATE, '%Y-%m-%d')
    df['Date'] = df['TransactionDT'].apply(lambda x : (startdate + datetime.timedelta(seconds=x)))

    df['Weekdays'] = df['Date'].dt.dayofweek
    df['Hours'] = df['Date'].dt.hour
    df['Days'] = df['Date'].dt.day

    df.drop(['Date'], axis=1, inplace=True)

    # DeviceInfo
    df.loc[df['DeviceInfo'].str.contains('SAMSUNG', na=False), 'DeviceInfo'] = 'SAMSUNG'
    df.loc[df['DeviceInfo'].str.contains('SM', na=False), 'DeviceInfo'] = 'SM'
    df.loc[df['DeviceInfo'].str.contains('rv', na=False), 'DeviceInfo'] = 'RV'
    df.loc[df['DeviceInfo'].str.contains('Moto', na=False), 'DeviceInfo'] = 'MOTO'
    df.loc[df['DeviceInfo'].str.contains('HUAWEI', na=False), 'DeviceInfo'] = 'HUAWEI'
    df.loc[df['DeviceInfo'].str.contains('Huawei', na=False), 'DeviceInfo'] = 'HUAWEI'
    df.loc[df['DeviceInfo'].str.contains('LG-', na=False), 'DeviceInfo'] = 'LG'
    df.loc[df['DeviceInfo'].str.contains('Android', na=False), 'DeviceInfo'] = 'ANDROID'
    df.loc[df['DeviceInfo'].str.contains('Linux', na=False), 'DeviceInfo'] = 'LINUX'
    df.loc[df['DeviceInfo'].str.contains('HTC', na=False), 'DeviceInfo'] = 'HTC'
    df.loc[df['DeviceInfo'].str.contains('Hisense', na=False), 'DeviceInfo'] = 'HISENSE'
    df.loc[df['DeviceInfo'].str.contains('Blade', na=False), 'DeviceInfo'] = 'BLADE'
    df.loc[df['DeviceInfo'].str.contains('BLADE', na=False), 'DeviceInfo'] = 'BLADE'
    df.loc[df['DeviceInfo'].str.contains('ASUS', na=False), 'DeviceInfo'] = 'ASUS'
    df.loc[df['DeviceInfo'].str.contains('Redmi', na=False), 'DeviceInfo'] = 'REDMI'
    df.loc[df['DeviceInfo'].str.contains('iOS', na=False), 'DeviceInfo'] = 'iOS'
    df.loc[df['DeviceInfo'].str.contains('MacOS', na=False), 'DeviceInfo'] = 'MacOS'
    device = ['SAMSUNG','SM','RV','MOTO','HUAWEI','LG','ANDROID','LINUX','HTC','HISENSE','BLADE','ASUS','REDMI',
              'Windows','iOS', 'MacOS', 'Trident/7.0']
    df.loc[(~df['DeviceInfo'].isin(device)) & (df['DeviceInfo'].notnull()), 'DeviceInfo'] = 'OTHERS'

    # id_30
    df.loc[df['id_30'].str.contains('Windows', na=False), 'id_30'] = 'WINDOWS'
    df.loc[df['id_30'].str.contains('iOS', na=False), 'id_30'] = 'iOS'
    df.loc[df['id_30'].str.contains('Mac OS X', na=False), 'id_30'] = 'MacOS'
    df.loc[df['id_30'].str.contains('Android', na=False), 'id_30'] = 'ANDROID'

    # id_31
    df.loc[df['id_31'].str.contains('chrome', na=False), 'id_31'] = 'CHROME'
    df.loc[df['id_31'].str.contains('firefox', na=False), 'id_31'] = 'FIREFOX'
    df.loc[df['id_31'].str.contains('edge', na=False), 'id_31'] = 'EDGE'
    df.loc[df['id_31'].str.contains('ie ', na=False), 'id_31'] = 'IE'
    df.loc[df['id_31'].str.contains('safari', na=False), 'id_31'] = 'SAFARI'
    df.loc[df['id_31'].str.contains('opera', na=False), 'id_31'] = 'OPERA'
    df.loc[df['id_31'].str.contains('samsung', na=False), 'id_31'] = 'SAMSUNG'
    df.loc[df['id_31'].str.contains('Samsung', na=False), 'id_31'] = 'SAMSUNG'
    df.loc[df['id_31'].str.contains('android', na=False), 'id_31'] = 'ANDROID'
    df.loc[df['id_31'].str.contains('Android', na=False), 'id_31'] = 'ANDROID'
    device2 = ['CHROME','FIREFOX','EDGE','IE','SAFARI','OPERA','SAMSUNG','ANDROID']
    df.loc[(~df['id_31'].isin(device2)) & (df['id_31'].notnull()), 'id_31'] = 'OTHERS'

    # id_33
    replace_to_others(df, 'id_33', cnt=10)

# %%
cat_feature_engineering(df_train)
cat_feature_engineering(df_test)

# %%
cat_col_t.extend(['Weekdays','Hours','Days'])
cat_col = [*cat_col_t, *cat_col_i]

# %% [markdown]
# ## 4.3 Feature Engineering for Numerical Features

# %% [markdown]
# 생략

# %% [markdown]
# ## 4.4 Missing Values

# %%
cat_col_null_over90 = list(cat_summary.loc[cat_summary['NullRt'] >= float(0.9), 'Name'].values)
num_col_null_over90 = list(num_summary.loc[num_summary['NullRt'] >= float(0.9), 'Name'].values)
col_null_over90 = [*cat_col_null_over90, *num_col_null_over90]

# %%
df_train = df_train.drop(col_null_over90, axis=1)
df_test = df_test.drop(col_null_over90, axis=1)

# %%
cat_col = [col for col in cat_col if col not in cat_col_null_over90]
num_col = [col for col in num_col if col not in num_col_null_over90]

# %% [markdown]
# ## 4.5 Encoding

# %%
for col in cat_col :
    if col in df_train.columns :
        le = LabelEncoder()
        le.fit(list(df_train[col].astype(str).values)
               + list(df_test[col].astype(str).values))
        df_train[col] = le.transform(list(df_train[col].astype(str).values))
        df_test[col] = le.transform(list(df_test[col].astype(str).values))

# %%
sn.noti('Feature Engineering Finished!')

# %% [markdown]
# # 5. Modeling

# %% [markdown]
# ## 5.1 Set X, y

# %%
df_train.head()
# Out:
#                isFraud  TransactionDT  TransactionAmt  ProductCD  card1  \
# TransactionID
# 2987000              0        1017844            68.5          4   4248
# 2987001              0        1017848            29.0          4   9979
# 2987002              0        1018317            59.0          4  11850
# 2987003              0        1018495            50.0          4   8796
# 2987004              0        1018526            50.0          1  11687
#
#                card2  card3  card4  card5  card6  ...   id_34  id_35  id_36  \
# TransactionID                                     ...
# 2987000          501     50      1     42      1  ...       4      2      2
# 2987001          304     50      2      2      1  ...       4      2      2
# 2987002          390     50      4     66      2  ...       4      2      2
# 2987003          467     50      2     17      2  ...       4      2      2
# 2987004          414     50      2      2      1  ...       3      1      0
#
#                id_37  id_38  DeviceType  DeviceInfo  Weekdays  Hours  Days
# TransactionID
# 2987000            2      2           2          18         5      0    11
# 2987001            2      2           2          18         5      0    11
# 2987002            2      2           2          18         5      0    11
# 2987003            2      2           2          18         5      0    11
# 2987004            1      1           1          13         5      0    11
#
# [5 rows x 423 columns]

# %%
y_train = df_train['isFraud']
X_train = df_train.drop('isFraud', axis=1)
X_test = df_test

# %% [markdown]
# ## 5.2 Make Validation set

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.2, random_state=0)

# %%
train_cnt = y_train.count()
valid_cnt = y_valid.count()
print('학습 세트 shape : {0}, 검증 세트 shape : {1}'.format(X_train.shape, X_valid.shape))

print('학습 세트 레이블 값 분포 비율')
print(y_train.value_counts()/train_cnt)
print('\n검증 세트 레이블 값 분포 비율')
print(y_valid.value_counts()/valid_cnt)
# Out:
# 학습 세트 shape : (472432, 422), 검증 세트 shape : (118108, 422)
# 학습 세트 레이블 값 분포 비율
# 0    0.964839
# 1    0.035161
# Name: isFraud, dtype: float64
#
# 검증 세트 레이블 값 분포 비율
# 0    0.965692
# 1    0.034308
# Name: isFraud, dtype: float64

# %% [markdown]
# ## 5.3 모델 학습

# %%
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score

xgb_clf = XGBClassifier(n_estimators=500, random_state=0)

xgb_clf.fit(X_train, y_train,
            early_stopping_rounds=100,
            eval_metric='auc',
            eval_set=[(X_train, y_train), (X_valid, y_valid)])

xgb_auc_score = roc_auc_score(y_valid, xgb_clf.predict_proba(X_valid)[:,1], average='macro')
print('ROC AUC : {0:.4f}'.format(xgb_auc_score))
sn.noti('XGBoost ROC AUC Score : {0:.4f}'.format(xgb_auc_score))
# Out:
# [0]	validation_0-auc:0.634645	validation_1-auc:0.640904
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 100 rounds.
# [1]	validation_0-auc:0.655195	validation_1-auc:0.661985
# [2]	validation_0-auc:0.735557	validation_1-auc:0.742603
# [3]	validation_0-auc:0.780065	validation_1-auc:0.784678
# [4]	validation_0-auc:0.779145	validation_1-auc:0.784262
# [5]	validation_0-auc:0.781518	validation_1-auc:0.786304
# [6]	validation_0-auc:0.781672	validation_1-auc:0.786485
# [7]	validation_0-auc:0.786442	validation_1-auc:0.790067
# [8]	validation_0-auc:0.794341	validation_1-auc:0.797695
# [9]	validation_0-auc:0.793684	validation_1-auc:0.796967
# [10]	validation_0-auc:0.794203	validation_1-auc:0.797566
# [11]	validation_0-auc:0.796274	validation_1-auc:0.799742
# [12]	validation_0-auc:0.79688	validation_1-auc:0.800637
# [13]	validation_0-auc:0.799742	validation_1-auc:0.803323
# [14]	validation_0-auc:0.800556	validation_1-auc:0.803958
# [15]	validation_0-auc:0.812855	validation_1-auc:0.815765
# [16]	validation_0-auc:0.814267	validation_1-auc:0.816933
# [17]	validation_0-auc:0.814557	validation_1-auc:0.817478
# [18]	validation_0-auc:0.818317	validation_1-auc:0.821604
# [19]	validation_0-auc:0.823109	validation_1-auc:0.826488
# [20]	validation_0-auc:0.828839	validation_1-auc:0.829907
# [21]	validation_0-auc:0.833855	validation_1-auc:0.835086
# [22]	validation_0-auc:0.834629	validation_1-auc:0.835857
# [23]	validation_0-auc:0.848807	validation_1-auc:0.849044
# [24]	validation_0-auc:0.850048	validation_1-auc:0.849901
# [25]	validation_0-auc:0.851005	validation_1-auc:0.850865
# [26]	validation_0-auc:0.852547	validation_1-auc:0.852221
# [27]	validation_0-auc:0.857481	validation_1-auc:0.856993
# [28]	validation_0-auc:0.857951	validation_1-auc:0.857436
# [29]	validation_0-auc:0.857964	validation_1-auc:0.857282
# [30]	validation_0-auc:0.85926	validation_1-auc:0.858428
# [31]	validation_0-auc:0.860577	validation_1-auc:0.859249
# [32]	validation_0-auc:0.862307	validation_1-auc:0.860595
# [33]	validation_0-auc:0.862791	validation_1-auc:0.861236
# [34]	validation_0-auc:0.863838	validation_1-auc:0.862265
# [35]	validation_0-auc:0.86482	validation_1-auc:0.863081
# [36]	validation_0-auc:0.865982	validation_1-auc:0.864178
# [37]	validation_0-auc:0.867435	validation_1-auc:0.866028
# [38]	validation_0-auc:0.867743	validation_1-auc:0.866689
# [39]	validation_0-auc:0.868746	validation_1-auc:0.867824
# [40]	validation_0-auc:0.869502	validation_1-auc:0.868344
# [41]	validation_0-auc:0.869959	validation_1-auc:0.868898
# [42]	validation_0-auc:0.87087	validation_1-auc:0.869675
# [43]	validation_0-auc:0.871441	validation_1-auc:0.869999
# [44]	validation_0-auc:0.87183	validation_1-auc:0.870699
# [45]	validation_0-auc:0.872594	validation_1-auc:0.871003
# [46]	validation_0-auc:0.872706	validation_1-auc:0.870966
# [47]	validation_0-auc:0.87367	validation_1-auc:0.871889
# [48]	validation_0-auc:0.874371	validation_1-auc:0.872391
# [49]	validation_0-auc:0.874913	validation_1-auc:0.872774
# [50]	validation_0-auc:0.875244	validation_1-auc:0.872928
# [51]	validation_0-auc:0.875802	validation_1-auc:0.873325
# [52]	validation_0-auc:0.876082	validation_1-auc:0.873754
# [53]	validation_0-auc:0.876773	validation_1-auc:0.874353
# [54]	validation_0-auc:0.877383	validation_1-auc:0.874959
# [55]	validation_0-auc:0.877558	validation_1-auc:0.87512
# [56]	validation_0-auc:0.878023	validation_1-auc:0.87568
# [57]	validation_0-auc:0.87865	validation_1-auc:0.876224
# [58]	validation_0-auc:0.879482	validation_1-auc:0.876889
# [59]	validation_0-auc:0.880124	validation_1-auc:0.877332
# [60]	validation_0-auc:0.88043	validation_1-auc:0.8776
# [61]	validation_0-auc:0.880772	validation_1-auc:0.877901
# [62]	validation_0-auc:0.880957	validation_1-auc:0.878194
# [63]	validation_0-auc:0.881093	validation_1-auc:0.878334
# [64]	validation_0-auc:0.881174	validation_1-auc:0.8785
# [65]	validation_0-auc:0.881631	validation_1-auc:0.879013
# [66]	validation_0-auc:0.88202	validation_1-auc:0.879373
# [67]	validation_0-auc:0.882211	validation_1-auc:0.879547
# [68]	validation_0-auc:0.882584	validation_1-auc:0.879841
# [69]	validation_0-auc:0.882864	validation_1-auc:0.880065
# [70]	validation_0-auc:0.883019	validation_1-auc:0.880173
# [71]	validation_0-auc:0.883095	validation_1-auc:0.880226
# [72]	validation_0-auc:0.883238	validation_1-auc:0.880602
# [73]	validation_0-auc:0.88342	validation_1-auc:0.8808
# [74]	validation_0-auc:0.883612	validation_1-auc:0.881138
# [75]	validation_0-auc:0.8844	validation_1-auc:0.881522
# [76]	validation_0-auc:0.884555	validation_1-auc:0.881659
# [77]	validation_0-auc:0.88497	validation_1-auc:0.882019
# [78]	validation_0-auc:0.885228	validation_1-auc:0.88229
# [79]	validation_0-auc:0.885534	validation_1-auc:0.882686
# [80]	validation_0-auc:0.885621	validation_1-auc:0.882767
# [81]	validation_0-auc:0.886253	validation_1-auc:0.883282
# [82]	validation_0-auc:0.886334	validation_1-auc:0.883355
# [83]	validation_0-auc:0.886657	validation_1-auc:0.883456
# [84]	validation_0-auc:0.886818	validation_1-auc:0.883662
# [85]	validation_0-auc:0.887386	validation_1-auc:0.884431
# [86]	validation_0-auc:0.887743	validation_1-auc:0.884572
# [87]	validation_0-auc:0.887845	validation_1-auc:0.884685
# [88]	validation_0-auc:0.888091	validation_1-auc:0.88501
# [89]	validation_0-auc:0.88828	validation_1-auc:0.885141
# [90]	validation_0-auc:0.88853	validation_1-auc:0.885348
# [91]	validation_0-auc:0.888687	validation_1-auc:0.885458
# [92]	validation_0-auc:0.888983	validation_1-auc:0.885669
# [93]	validation_0-auc:0.889347	validation_1-auc:0.886128
# [94]	validation_0-auc:0.889777	validation_1-auc:0.886592
# [95]	validation_0-auc:0.88998	validation_1-auc:0.886813
# [96]	validation_0-auc:0.89015	validation_1-auc:0.886952
# [97]	validation_0-auc:0.890425	validation_1-auc:0.887356
# [98]	validation_0-auc:0.890726	validation_1-auc:0.887638
# [99]	validation_0-auc:0.891005	validation_1-auc:0.887843
# [100]	validation_0-auc:0.891213	validation_1-auc:0.888006
# [101]	validation_0-auc:0.89129	validation_1-auc:0.888057
# [102]	validation_0-auc:0.891427	validation_1-auc:0.888162
# [103]	validation_0-auc:0.8919	validation_1-auc:0.88872
# [104]	validation_0-auc:0.892209	validation_1-auc:0.889053
# [105]	validation_0-auc:0.892297	validation_1-auc:0.889148
# [106]	validation_0-auc:0.892457	validation_1-auc:0.88928
# [107]	validation_0-auc:0.892627	validation_1-auc:0.889463
# [108]	validation_0-auc:0.892808	validation_1-auc:0.889611
# [109]	validation_0-auc:0.892948	validation_1-auc:0.889723
# [110]	validation_0-auc:0.8932	validation_1-auc:0.889952
# [111]	validation_0-auc:0.893273	validation_1-auc:0.890035
# [112]	validation_0-auc:0.893392	validation_1-auc:0.89012
# [113]	validation_0-auc:0.893438	validation_1-auc:0.890195
# [114]	validation_0-auc:0.893595	validation_1-auc:0.890347
# [115]	validation_0-auc:0.893728	validation_1-auc:0.890458
# [116]	validation_0-auc:0.893799	validation_1-auc:0.890537
# [117]	validation_0-auc:0.893967	validation_1-auc:0.890651
# [118]	validation_0-auc:0.894025	validation_1-auc:0.890682
# [119]	validation_0-auc:0.894264	validation_1-auc:0.89087
# [120]	validation_0-auc:0.894339	validation_1-auc:0.890931
# [121]	validation_0-auc:0.894729	validation_1-auc:0.89122
# [122]	validation_0-auc:0.894877	validation_1-auc:0.891381
# [123]	validation_0-auc:0.895087	validation_1-auc:0.891515
# [124]	validation_0-auc:0.895182	validation_1-auc:0.891606
# [125]	validation_0-auc:0.895235	validation_1-auc:0.891636
# [126]	validation_0-auc:0.895372	validation_1-auc:0.891765
# [127]	validation_0-auc:0.895432	validation_1-auc:0.891831
# [128]	validation_0-auc:0.895586	validation_1-auc:0.891893
# [129]	validation_0-auc:0.895753	validation_1-auc:0.892131
# [130]	validation_0-auc:0.896061	validation_1-auc:0.892419
# [131]	validation_0-auc:0.89611	validation_1-auc:0.892458
# [132]	validation_0-auc:0.896284	validation_1-auc:0.892684
# [133]	validation_0-auc:0.896457	validation_1-auc:0.892866
# [134]	validation_0-auc:0.896519	validation_1-auc:0.892927
# [135]	validation_0-auc:0.896689	validation_1-auc:0.893052
# [136]	validation_0-auc:0.89689	validation_1-auc:0.893242
# [137]	validation_0-auc:0.897012	validation_1-auc:0.893431
# [138]	validation_0-auc:0.897039	validation_1-auc:0.893428
# [139]	validation_0-auc:0.897074	validation_1-auc:0.893454
# [140]	validation_0-auc:0.897139	validation_1-auc:0.893552
# [141]	validation_0-auc:0.897311	validation_1-auc:0.893722
# [142]	validation_0-auc:0.897546	validation_1-auc:0.893901
# [143]	validation_0-auc:0.897648	validation_1-auc:0.893962
# [144]	validation_0-auc:0.897827	validation_1-auc:0.894141
# [145]	validation_0-auc:0.897934	validation_1-auc:0.894178
# [146]	validation_0-auc:0.898239	validation_1-auc:0.894409
# [147]	validation_0-auc:0.898386	validation_1-auc:0.894578
# [148]	validation_0-auc:0.898393	validation_1-auc:0.894609
# [149]	validation_0-auc:0.898473	validation_1-auc:0.894679
# [150]	validation_0-auc:0.898815	validation_1-auc:0.894937
# [151]	validation_0-auc:0.899135	validation_1-auc:0.895109
# [152]	validation_0-auc:0.899209	validation_1-auc:0.895173
# [153]	validation_0-auc:0.899269	validation_1-auc:0.895244
# [154]	validation_0-auc:0.899365	validation_1-auc:0.895318
# [155]	validation_0-auc:0.89947	validation_1-auc:0.895397
# [156]	validation_0-auc:0.899525	validation_1-auc:0.895449
# [157]	validation_0-auc:0.89985	validation_1-auc:0.895614
# [158]	validation_0-auc:0.899893	validation_1-auc:0.895666
# [159]	validation_0-auc:0.900005	validation_1-auc:0.895725
# [160]	validation_0-auc:0.900146	validation_1-auc:0.895882
# [161]	validation_0-auc:0.900325	validation_1-auc:0.895992
# [162]	validation_0-auc:0.900514	validation_1-auc:0.896188
# [163]	validation_0-auc:0.900791	validation_1-auc:0.896431
# [164]	validation_0-auc:0.900991	validation_1-auc:0.896654
# [165]	validation_0-auc:0.900986	validation_1-auc:0.896643
# [166]	validation_0-auc:0.901042	validation_1-auc:0.896706
# [167]	validation_0-auc:0.901083	validation_1-auc:0.896743
# [168]	validation_0-auc:0.901144	validation_1-auc:0.896827
# [169]	validation_0-auc:0.901193	validation_1-auc:0.896864
# [170]	validation_0-auc:0.901279	validation_1-auc:0.896943
# [171]	validation_0-auc:0.901433	validation_1-auc:0.897038
# [172]	validation_0-auc:0.901452	validation_1-auc:0.897049
# [173]	validation_0-auc:0.901775	validation_1-auc:0.897398
# [174]	validation_0-auc:0.901818	validation_1-auc:0.897442
# [175]	validation_0-auc:0.901901	validation_1-auc:0.897512
# [176]	validation_0-auc:0.902026	validation_1-auc:0.897623
# [177]	validation_0-auc:0.90208	validation_1-auc:0.89769
# [178]	validation_0-auc:0.902228	validation_1-auc:0.897832
# [179]	validation_0-auc:0.902364	validation_1-auc:0.89804
# [180]	validation_0-auc:0.902455	validation_1-auc:0.898091
# [181]	validation_0-auc:0.902571	validation_1-auc:0.898249
# [182]	validation_0-auc:0.902604	validation_1-auc:0.898276
# [183]	validation_0-auc:0.902731	validation_1-auc:0.89841
# [184]	validation_0-auc:0.902752	validation_1-auc:0.898437
# [185]	validation_0-auc:0.902821	validation_1-auc:0.898469
# [186]	validation_0-auc:0.902846	validation_1-auc:0.898509
# [187]	validation_0-auc:0.903131	validation_1-auc:0.898736
# [188]	validation_0-auc:0.903197	validation_1-auc:0.898805
# [189]	validation_0-auc:0.903245	validation_1-auc:0.898824
# [190]	validation_0-auc:0.90328	validation_1-auc:0.898858
# [191]	validation_0-auc:0.903412	validation_1-auc:0.898929
# [192]	validation_0-auc:0.903445	validation_1-auc:0.898955
# [193]	validation_0-auc:0.903489	validation_1-auc:0.898995
# [194]	validation_0-auc:0.903535	validation_1-auc:0.899032
# [195]	validation_0-auc:0.903613	validation_1-auc:0.899124
# [196]	validation_0-auc:0.903678	validation_1-auc:0.899179
# [197]	validation_0-auc:0.903783	validation_1-auc:0.899207
# [198]	validation_0-auc:0.903886	validation_1-auc:0.899302
# [199]	validation_0-auc:0.904138	validation_1-auc:0.899522
# [200]	validation_0-auc:0.90419	validation_1-auc:0.899586
# [201]	validation_0-auc:0.904334	validation_1-auc:0.899811
# [202]	validation_0-auc:0.904379	validation_1-auc:0.899875
# [203]	validation_0-auc:0.904568	validation_1-auc:0.899983
# [204]	validation_0-auc:0.904607	validation_1-auc:0.900028
# [205]	validation_0-auc:0.904679	validation_1-auc:0.900093
# [206]	validation_0-auc:0.904687	validation_1-auc:0.900087
# [207]	validation_0-auc:0.904801	validation_1-auc:0.900166
# [208]	validation_0-auc:0.904865	validation_1-auc:0.900227
# [209]	validation_0-auc:0.905053	validation_1-auc:0.900321
# [210]	validation_0-auc:0.905329	validation_1-auc:0.900572
# [211]	validation_0-auc:0.905492	validation_1-auc:0.9007
# [212]	validation_0-auc:0.905571	validation_1-auc:0.900769
# [213]	validation_0-auc:0.905679	validation_1-auc:0.900794
# [214]	validation_0-auc:0.905945	validation_1-auc:0.901125
# [215]	validation_0-auc:0.906123	validation_1-auc:0.901244
# [216]	validation_0-auc:0.906196	validation_1-auc:0.901268
# [217]	validation_0-auc:0.906241	validation_1-auc:0.901309
# [218]	validation_0-auc:0.906388	validation_1-auc:0.901548
# [219]	validation_0-auc:0.906417	validation_1-auc:0.901598
# [220]	validation_0-auc:0.906634	validation_1-auc:0.901747
# [221]	validation_0-auc:0.90668	validation_1-auc:0.90177
# [222]	validation_0-auc:0.906752	validation_1-auc:0.901824
# [223]	validation_0-auc:0.906779	validation_1-auc:0.90187
# [224]	validation_0-auc:0.906892	validation_1-auc:0.901977
# [225]	validation_0-auc:0.906949	validation_1-auc:0.902015
# [226]	validation_0-auc:0.907	validation_1-auc:0.902105
# [227]	validation_0-auc:0.907035	validation_1-auc:0.902108
# [228]	validation_0-auc:0.907107	validation_1-auc:0.902165
# [229]	validation_0-auc:0.90717	validation_1-auc:0.902207
# [230]	validation_0-auc:0.907254	validation_1-auc:0.90228
# [231]	validation_0-auc:0.907294	validation_1-auc:0.90232
# [232]	validation_0-auc:0.907322	validation_1-auc:0.90234
# [233]	validation_0-auc:0.90743	validation_1-auc:0.90241
# [234]	validation_0-auc:0.907432	validation_1-auc:0.902427
# [235]	validation_0-auc:0.907497	validation_1-auc:0.902492
# [236]	validation_0-auc:0.907533	validation_1-auc:0.902522
# [237]	validation_0-auc:0.907575	validation_1-auc:0.902551
# [238]	validation_0-auc:0.907661	validation_1-auc:0.902639
# [239]	validation_0-auc:0.907729	validation_1-auc:0.902676
# [240]	validation_0-auc:0.907784	validation_1-auc:0.902754
# [241]	validation_0-auc:0.907822	validation_1-auc:0.90279
# [242]	validation_0-auc:0.90786	validation_1-auc:0.902804
# [243]	validation_0-auc:0.907955	validation_1-auc:0.902874
# [244]	validation_0-auc:0.908059	validation_1-auc:0.903007
# [245]	validation_0-auc:0.908147	validation_1-auc:0.903042
# [246]	validation_0-auc:0.908314	validation_1-auc:0.903158
# [247]	validation_0-auc:0.908568	validation_1-auc:0.903397
# [248]	validation_0-auc:0.908809	validation_1-auc:0.903629
# [249]	validation_0-auc:0.908918	validation_1-auc:0.903692
# [250]	validation_0-auc:0.909041	validation_1-auc:0.903793
# [251]	validation_0-auc:0.909078	validation_1-auc:0.9038
# [252]	validation_0-auc:0.90911	validation_1-auc:0.903826
# [253]	validation_0-auc:0.909143	validation_1-auc:0.903846
# [254]	validation_0-auc:0.909319	validation_1-auc:0.904114
# [255]	validation_0-auc:0.909403	validation_1-auc:0.904219
# [256]	validation_0-auc:0.909436	validation_1-auc:0.904256
# [257]	validation_0-auc:0.909479	validation_1-auc:0.904272
# [258]	validation_0-auc:0.909551	validation_1-auc:0.904329
# [259]	validation_0-auc:0.909668	validation_1-auc:0.904449
# [260]	validation_0-auc:0.909705	validation_1-auc:0.904498
# [261]	validation_0-auc:0.90977	validation_1-auc:0.904567
# [262]	validation_0-auc:0.9098	validation_1-auc:0.904578
# [263]	validation_0-auc:0.909921	validation_1-auc:0.904658
# [264]	validation_0-auc:0.909951	validation_1-auc:0.904736
# [265]	validation_0-auc:0.910006	validation_1-auc:0.904819
# [266]	validation_0-auc:0.910132	validation_1-auc:0.904957
# [267]	validation_0-auc:0.91025	validation_1-auc:0.905105
# [268]	validation_0-auc:0.910354	validation_1-auc:0.905171
# [269]	validation_0-auc:0.910535	validation_1-auc:0.905367
# [270]	validation_0-auc:0.910685	validation_1-auc:0.905482
# [271]	validation_0-auc:0.910786	validation_1-auc:0.905563
# [272]	validation_0-auc:0.910965	validation_1-auc:0.905745
# [273]	validation_0-auc:0.910994	validation_1-auc:0.905792
# [274]	validation_0-auc:0.911074	validation_1-auc:0.905857
# [275]	validation_0-auc:0.911107	validation_1-auc:0.905881
# [276]	validation_0-auc:0.911132	validation_1-auc:0.905891
# [277]	validation_0-auc:0.911168	validation_1-auc:0.905921
# [278]	validation_0-auc:0.911244	validation_1-auc:0.905954
# [279]	validation_0-auc:0.911313	validation_1-auc:0.905971
# [280]	validation_0-auc:0.911352	validation_1-auc:0.905997
# [281]	validation_0-auc:0.911373	validation_1-auc:0.906012
# [282]	validation_0-auc:0.911492	validation_1-auc:0.906097
# [283]	validation_0-auc:0.9116	validation_1-auc:0.906188
# [284]	validation_0-auc:0.911661	validation_1-auc:0.906288
# [285]	validation_0-auc:0.911838	validation_1-auc:0.906516
# [286]	validation_0-auc:0.912006	validation_1-auc:0.906712
# [287]	validation_0-auc:0.912056	validation_1-auc:0.906732
# [288]	validation_0-auc:0.912145	validation_1-auc:0.906799
# [289]	validation_0-auc:0.912171	validation_1-auc:0.906801
# [290]	validation_0-auc:0.912263	validation_1-auc:0.906865
# [291]	validation_0-auc:0.91235	validation_1-auc:0.906931
# [292]	validation_0-auc:0.912378	validation_1-auc:0.906972
# [293]	validation_0-auc:0.912447	validation_1-auc:0.907048
# [294]	validation_0-auc:0.912472	validation_1-auc:0.907077
# [295]	validation_0-auc:0.91249	validation_1-auc:0.907089
# [296]	validation_0-auc:0.912539	validation_1-auc:0.907077
# [297]	validation_0-auc:0.912612	validation_1-auc:0.907139
# [298]	validation_0-auc:0.912781	validation_1-auc:0.907284
# [299]	validation_0-auc:0.912886	validation_1-auc:0.907344
# [300]	validation_0-auc:0.913012	validation_1-auc:0.907486
# [301]	validation_0-auc:0.913163	validation_1-auc:0.907539
# [302]	validation_0-auc:0.913191	validation_1-auc:0.907551
# [303]	validation_0-auc:0.913277	validation_1-auc:0.907635
# [304]	validation_0-auc:0.913283	validation_1-auc:0.907633
# [305]	validation_0-auc:0.91329	validation_1-auc:0.907637
# [306]	validation_0-auc:0.913334	validation_1-auc:0.907673
# [307]	validation_0-auc:0.913436	validation_1-auc:0.907835
# [308]	validation_0-auc:0.913508	validation_1-auc:0.907883
# [309]	validation_0-auc:0.913533	validation_1-auc:0.907911
# [310]	validation_0-auc:0.913561	validation_1-auc:0.90793
# [311]	validation_0-auc:0.913689	validation_1-auc:0.907934
# [312]	validation_0-auc:0.913733	validation_1-auc:0.907973
# [313]	validation_0-auc:0.913736	validation_1-auc:0.907976
# [314]	validation_0-auc:0.913775	validation_1-auc:0.90799
# [315]	validation_0-auc:0.913871	validation_1-auc:0.908052
# [316]	validation_0-auc:0.913881	validation_1-auc:0.908057
# [317]	validation_0-auc:0.913888	validation_1-auc:0.908073
# [318]	validation_0-auc:0.914015	validation_1-auc:0.908159
# [319]	validation_0-auc:0.914085	validation_1-auc:0.908167
# [320]	validation_0-auc:0.914287	validation_1-auc:0.908389
# [321]	validation_0-auc:0.914357	validation_1-auc:0.908433
# [322]	validation_0-auc:0.914431	validation_1-auc:0.908465
# [323]	validation_0-auc:0.914482	validation_1-auc:0.908479
# [324]	validation_0-auc:0.9145	validation_1-auc:0.908483
# [325]	validation_0-auc:0.914568	validation_1-auc:0.908553
# [326]	validation_0-auc:0.914748	validation_1-auc:0.908798
# [327]	validation_0-auc:0.914755	validation_1-auc:0.908798
# [328]	validation_0-auc:0.91478	validation_1-auc:0.908812
# [329]	validation_0-auc:0.91481	validation_1-auc:0.90885
# [330]	validation_0-auc:0.914847	validation_1-auc:0.908872
# [331]	validation_0-auc:0.914871	validation_1-auc:0.908896
# [332]	validation_0-auc:0.914931	validation_1-auc:0.90894
# [333]	validation_0-auc:0.914996	validation_1-auc:0.908965
# [334]	validation_0-auc:0.915027	validation_1-auc:0.908997
# [335]	validation_0-auc:0.915034	validation_1-auc:0.908999
# [336]	validation_0-auc:0.915079	validation_1-auc:0.909034
# [337]	validation_0-auc:0.915092	validation_1-auc:0.909055
# [338]	validation_0-auc:0.915139	validation_1-auc:0.909075
# [339]	validation_0-auc:0.915186	validation_1-auc:0.909102
# [340]	validation_0-auc:0.915214	validation_1-auc:0.909131
# [341]	validation_0-auc:0.915233	validation_1-auc:0.909155
# [342]	validation_0-auc:0.915272	validation_1-auc:0.909175
# [343]	validation_0-auc:0.915377	validation_1-auc:0.909261
# [344]	validation_0-auc:0.915426	validation_1-auc:0.909307
# [345]	validation_0-auc:0.915501	validation_1-auc:0.909374
# [346]	validation_0-auc:0.915524	validation_1-auc:0.9094
# [347]	validation_0-auc:0.915549	validation_1-auc:0.909416
# [348]	validation_0-auc:0.915552	validation_1-auc:0.90942
# [349]	validation_0-auc:0.915572	validation_1-auc:0.909437
# [350]	validation_0-auc:0.915675	validation_1-auc:0.909554
# [351]	validation_0-auc:0.915724	validation_1-auc:0.909557
# [352]	validation_0-auc:0.91574	validation_1-auc:0.909569
# [353]	validation_0-auc:0.915756	validation_1-auc:0.909589
# [354]	validation_0-auc:0.915781	validation_1-auc:0.909625
# [355]	validation_0-auc:0.91581	validation_1-auc:0.909657
# [356]	validation_0-auc:0.915869	validation_1-auc:0.909694
# [357]	validation_0-auc:0.915965	validation_1-auc:0.909781
# [358]	validation_0-auc:0.915986	validation_1-auc:0.909792
# [359]	validation_0-auc:0.916007	validation_1-auc:0.909805
# [360]	validation_0-auc:0.916054	validation_1-auc:0.909861
# [361]	validation_0-auc:0.916089	validation_1-auc:0.909824
# [362]	validation_0-auc:0.916157	validation_1-auc:0.909874
# [363]	validation_0-auc:0.916172	validation_1-auc:0.909889
# [364]	validation_0-auc:0.916237	validation_1-auc:0.90994
# [365]	validation_0-auc:0.916396	validation_1-auc:0.910115
# [366]	validation_0-auc:0.916464	validation_1-auc:0.910219
# [367]	validation_0-auc:0.91653	validation_1-auc:0.910247
# [368]	validation_0-auc:0.916574	validation_1-auc:0.910295
# [369]	validation_0-auc:0.916591	validation_1-auc:0.910302
# [370]	validation_0-auc:0.916625	validation_1-auc:0.910333
# [371]	validation_0-auc:0.916673	validation_1-auc:0.910356
# [372]	validation_0-auc:0.916697	validation_1-auc:0.910372
# [373]	validation_0-auc:0.916707	validation_1-auc:0.910381
# [374]	validation_0-auc:0.916861	validation_1-auc:0.910551
# [375]	validation_0-auc:0.916879	validation_1-auc:0.910556
# [376]	validation_0-auc:0.916938	validation_1-auc:0.910604
# [377]	validation_0-auc:0.916946	validation_1-auc:0.910602
# [378]	validation_0-auc:0.916967	validation_1-auc:0.910616
# [379]	validation_0-auc:0.916957	validation_1-auc:0.910613
# [380]	validation_0-auc:0.916947	validation_1-auc:0.910615
# [381]	validation_0-auc:0.916963	validation_1-auc:0.910627
# [382]	validation_0-auc:0.91711	validation_1-auc:0.910778
# [383]	validation_0-auc:0.917175	validation_1-auc:0.910851
# [384]	validation_0-auc:0.917272	validation_1-auc:0.91092
# [385]	validation_0-auc:0.917335	validation_1-auc:0.910994
# [386]	validation_0-auc:0.917355	validation_1-auc:0.910999
# [387]	validation_0-auc:0.917403	validation_1-auc:0.911032
# [388]	validation_0-auc:0.917573	validation_1-auc:0.911182
# [389]	validation_0-auc:0.917872	validation_1-auc:0.911534
# [390]	validation_0-auc:0.917948	validation_1-auc:0.91157
# [391]	validation_0-auc:0.918029	validation_1-auc:0.911634
# [392]	validation_0-auc:0.918061	validation_1-auc:0.911669
# [393]	validation_0-auc:0.918093	validation_1-auc:0.911707
# [394]	validation_0-auc:0.918109	validation_1-auc:0.911722
# [395]	validation_0-auc:0.918152	validation_1-auc:0.911748
# [396]	validation_0-auc:0.918161	validation_1-auc:0.911756
# [397]	validation_0-auc:0.918185	validation_1-auc:0.91178
# [398]	validation_0-auc:0.918199	validation_1-auc:0.911795
# [399]	validation_0-auc:0.918216	validation_1-auc:0.911809
# [400]	validation_0-auc:0.918242	validation_1-auc:0.911824
# [401]	validation_0-auc:0.918389	validation_1-auc:0.911937
# [402]	validation_0-auc:0.918392	validation_1-auc:0.91194
# [403]	validation_0-auc:0.918425	validation_1-auc:0.912001
# [404]	validation_0-auc:0.918481	validation_1-auc:0.91203
# [405]	validation_0-auc:0.918588	validation_1-auc:0.912115
# [406]	validation_0-auc:0.918641	validation_1-auc:0.912188
# [407]	validation_0-auc:0.918755	validation_1-auc:0.91233
# [408]	validation_0-auc:0.918794	validation_1-auc:0.912347
# [409]	validation_0-auc:0.918942	validation_1-auc:0.912531
# [410]	validation_0-auc:0.919029	validation_1-auc:0.912586
# [411]	validation_0-auc:0.919041	validation_1-auc:0.912599
# [412]	validation_0-auc:0.919072	validation_1-auc:0.912588
# [413]	validation_0-auc:0.919079	validation_1-auc:0.91259
# [414]	validation_0-auc:0.919123	validation_1-auc:0.912574
# [415]	validation_0-auc:0.91917	validation_1-auc:0.91261
# [416]	validation_0-auc:0.919181	validation_1-auc:0.912615
# [417]	validation_0-auc:0.919202	validation_1-auc:0.912625
# [418]	validation_0-auc:0.919256	validation_1-auc:0.91266
# [419]	validation_0-auc:0.919283	validation_1-auc:0.912705
# [420]	validation_0-auc:0.919424	validation_1-auc:0.912828
# [421]	validation_0-auc:0.91948	validation_1-auc:0.912867
# [422]	validation_0-auc:0.919539	validation_1-auc:0.912917
# [423]	validation_0-auc:0.919582	validation_1-auc:0.912992
# [424]	validation_0-auc:0.919625	validation_1-auc:0.913036
# [425]	validation_0-auc:0.919667	validation_1-auc:0.913076
# [426]	validation_0-auc:0.919693	validation_1-auc:0.913125
# [427]	validation_0-auc:0.919734	validation_1-auc:0.913171
# [428]	validation_0-auc:0.919768	validation_1-auc:0.91317
# [429]	validation_0-auc:0.919828	validation_1-auc:0.913236
# [430]	validation_0-auc:0.919938	validation_1-auc:0.913346
# [431]	validation_0-auc:0.919957	validation_1-auc:0.913353
# [432]	validation_0-auc:0.920009	validation_1-auc:0.913396
# [433]	validation_0-auc:0.920176	validation_1-auc:0.913508
# [434]	validation_0-auc:0.920212	validation_1-auc:0.913522
# [435]	validation_0-auc:0.920231	validation_1-auc:0.913531
# [436]	validation_0-auc:0.920234	validation_1-auc:0.913534
# [437]	validation_0-auc:0.920233	validation_1-auc:0.913531
# [438]	validation_0-auc:0.920239	validation_1-auc:0.913526
# [439]	validation_0-auc:0.920281	validation_1-auc:0.913563
# [440]	validation_0-auc:0.920303	validation_1-auc:0.913578
# [441]	validation_0-auc:0.920313	validation_1-auc:0.913591
# [442]	validation_0-auc:0.920372	validation_1-auc:0.913624
# [443]	validation_0-auc:0.920413	validation_1-auc:0.91366
# [444]	validation_0-auc:0.920525	validation_1-auc:0.913817
# [445]	validation_0-auc:0.920577	validation_1-auc:0.913844
# [446]	validation_0-auc:0.920602	validation_1-auc:0.913857
# [447]	validation_0-auc:0.920626	validation_1-auc:0.91385
# [448]	validation_0-auc:0.920734	validation_1-auc:0.914002
# [449]	validation_0-auc:0.920753	validation_1-auc:0.91402
# [450]	validation_0-auc:0.920815	validation_1-auc:0.914091
# [451]	validation_0-auc:0.920838	validation_1-auc:0.914092
# [452]	validation_0-auc:0.920861	validation_1-auc:0.914103
# [453]	validation_0-auc:0.920873	validation_1-auc:0.914113
# [454]	validation_0-auc:0.920898	validation_1-auc:0.91413
# [455]	validation_0-auc:0.92092	validation_1-auc:0.914145
# [456]	validation_0-auc:0.920933	validation_1-auc:0.914152
# [457]	validation_0-auc:0.921007	validation_1-auc:0.914216
# [458]	validation_0-auc:0.921015	validation_1-auc:0.914211
# [459]	validation_0-auc:0.921034	validation_1-auc:0.914229
# [460]	validation_0-auc:0.921037	validation_1-auc:0.914232
# [461]	validation_0-auc:0.921085	validation_1-auc:0.914261
# [462]	validation_0-auc:0.921127	validation_1-auc:0.914293
# [463]	validation_0-auc:0.921141	validation_1-auc:0.914302
# [464]	validation_0-auc:0.921209	validation_1-auc:0.91436
# [465]	validation_0-auc:0.921307	validation_1-auc:0.914467
# [466]	validation_0-auc:0.92135	validation_1-auc:0.914508
# [467]	validation_0-auc:0.921416	validation_1-auc:0.914573
# [468]	validation_0-auc:0.921465	validation_1-auc:0.91464
# [469]	validation_0-auc:0.921514	validation_1-auc:0.914626
# [470]	validation_0-auc:0.921609	validation_1-auc:0.91471
# [471]	validation_0-auc:0.921673	validation_1-auc:0.914777
# [472]	validation_0-auc:0.921686	validation_1-auc:0.914791
# [473]	validation_0-auc:0.921706	validation_1-auc:0.914789
# [474]	validation_0-auc:0.921766	validation_1-auc:0.914834
# [475]	validation_0-auc:0.921775	validation_1-auc:0.914844
# [476]	validation_0-auc:0.921887	validation_1-auc:0.914921
# [477]	validation_0-auc:0.921952	validation_1-auc:0.915004
# [478]	validation_0-auc:0.921959	validation_1-auc:0.915005
# [479]	validation_0-auc:0.922037	validation_1-auc:0.915109
# [480]	validation_0-auc:0.9221	validation_1-auc:0.91516
# [481]	validation_0-auc:0.922184	validation_1-auc:0.91528
# [482]	validation_0-auc:0.922262	validation_1-auc:0.915304
# [483]	validation_0-auc:0.92234	validation_1-auc:0.915353
# [484]	validation_0-auc:0.922412	validation_1-auc:0.915418
# [485]	validation_0-auc:0.922414	validation_1-auc:0.915419
# [486]	validation_0-auc:0.922432	validation_1-auc:0.915441
# [487]	validation_0-auc:0.92246	validation_1-auc:0.915445
# [488]	validation_0-auc:0.922449	validation_1-auc:0.915439
# [489]	validation_0-auc:0.922459	validation_1-auc:0.915448
# [490]	validation_0-auc:0.922486	validation_1-auc:0.915443
# [491]	validation_0-auc:0.922501	validation_1-auc:0.915453
# [492]	validation_0-auc:0.922532	validation_1-auc:0.915439
# [493]	validation_0-auc:0.922555	validation_1-auc:0.915444
# [494]	validation_0-auc:0.922574	validation_1-auc:0.915454
# [495]	validation_0-auc:0.922637	validation_1-auc:0.915514
# [496]	validation_0-auc:0.922655	validation_1-auc:0.915527
# [497]	validation_0-auc:0.922696	validation_1-auc:0.915571
# [498]	validation_0-auc:0.922725	validation_1-auc:0.915566
# [499]	validation_0-auc:0.922761	validation_1-auc:0.915591
# ROC AUC : 0.9156

# %% [markdown]
# # 6. Make Submission

# %%
y_pred = xgb_clf.predict_proba(X_test)[:,1]

sample_submission['isFraud'] = y_pred
sample_submission.to_csv('v010_xgboost.csv', index=False)

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
train_i = pd.read_csv('../../input/train_identity.csv')

# %%
def make_summary(df) :
    print(f"Dataset shape: {df.shape}")
    summary = pd.DataFrame(df.dtypes, columns=['dtypes'])
    summary = summary.reset_index()
    summary['Name'] = summary['index']
    summary = summary[['Name','dtypes']]
    summary['Missing'] = df.isnull().sum().values
    summary['Uniques'] = df.nunique().values
    
    return summary

# %%
summary_i = make_summary(train_i)
summary_i.head(10)
# Out:
# Dataset shape: (144233, 41)
#             Name   dtypes  Missing  Uniques
# 0  TransactionID    int64        0   144233
# 1          id_01  float64        0       77
# 2          id_02  float64     3361   115655
# 3          id_03  float64    77909       24
# 4          id_04  float64    77909       15
# 5          id_05  float64     7368       93
# 6          id_06  float64     7368      101
# 7          id_07  float64   139078       84
# 8          id_08  float64   139078       94
# 9          id_09  float64    69307       46

# %%
summary_i
# Out:
#              Name   dtypes  Missing  Uniques
# 0   TransactionID    int64        0   144233
# 1           id_01  float64        0       77
# 2           id_02  float64     3361   115655
# 3           id_03  float64    77909       24
# 4           id_04  float64    77909       15
# 5           id_05  float64     7368       93
# 6           id_06  float64     7368      101
# 7           id_07  float64   139078       84
# 8           id_08  float64   139078       94
# 9           id_09  float64    69307       46
# 10          id_10  float64    69307       62
# 11          id_11  float64     3255      365
# 12          id_12   object        0        2
# 13          id_13  float64    16913       54
# 14          id_14  float64    64189       25
# 15          id_15   object     3248        3
# 16          id_16   object    14893        2
# 17          id_17  float64     4864      104
# 18          id_18  float64    99120       18
# 19          id_19  float64     4915      522
# ...

# %%
train_i.DeviceType.value_counts()
# Out:
# desktop    85165
# mobile     55645
# Name: DeviceType, dtype: int64

# %%
train_i.DeviceInfo.value_counts()
# Out:
# Windows                           47722
# iOS Device                        19782
# MacOS                             12573
# Trident/7.0                        7440
# rv:11.0                            1901
# rv:57.0                             962
# SM-J700M Build/MMB29K               549
# SM-G610M Build/MMB29K               461
# SM-G531H Build/LMY48B               410
# rv:59.0                             362
# SM-G935F Build/NRD90M               334
# SM-G955U Build/NRD90M               328
# SM-G532M Build/MMB29T               316
# ALE-L23 Build/HuaweiALE-L23         312
# SM-G950U Build/NRD90M               290
# SM-G930V Build/NRD90M               274
# rv:58.0                             269
# rv:52.0                             256
# SAMSUNG                             235
# SM-G950F Build/NRD90M               225
# Moto G (4) Build/NPJ25.93-14.7      219
# SM-N950U Build/NMF26X               209
# SM-A300H Build/LRX22G               203
# ...

# %%
g = sns.countplot(x='id_12', data=train_i)

# %%
id_list = list(summary_i.Name)

# %%
id_list
# Out:
# ['TransactionID',
#  'id_01',
#  'id_02',
#  'id_03',
#  'id_04',
#  'id_05',
#  'id_06',
#  'id_07',
#  'id_08',
#  'id_09',
#  'id_10',
#  'id_11',
#  'id_12',
#  'id_13',
#  'id_14',
#  'id_15',
#  'id_16',
#  'id_17',
#  'id_18',
#  'id_19',
#  'id_20',
#  'id_21',
#  'id_22',
#  'id_23',
#  'id_24',
#  'id_25',
#  'id_26',
#  'id_27',
#  'id_28',
#  'id_29',
#  'id_30',
#  'id_31',
#  'id_32',
#  'id_33',
#  'id_34',
#  'id_35',
#  'id_36',
#  'id_37',
#  'id_38',
#  'DeviceType',
#  'DeviceInfo']

# %%
id_list.remove('TransactionID')
id_list.remove('DeviceType')
id_list.remove('DeviceInfo')
id_list
# Out:
# ['id_01',
#  'id_02',
#  'id_03',
#  'id_04',
#  'id_05',
#  'id_06',
#  'id_07',
#  'id_08',
#  'id_09',
#  'id_10',
#  'id_11',
#  'id_12',
#  'id_13',
#  'id_14',
#  'id_15',
#  'id_16',
#  'id_17',
#  'id_18',
#  'id_19',
#  'id_20',
#  'id_21',
#  'id_22',
#  'id_23',
#  'id_24',
#  'id_25',
#  'id_26',
#  'id_27',
#  'id_28',
#  'id_29',
#  'id_30',
#  'id_31',
#  'id_32',
#  'id_33',
#  'id_34',
#  'id_35',
#  'id_36',
#  'id_37',
#  'id_38']

# %%
for col in id_list :
    g = sns.countplot(x=col, data=train_i)
